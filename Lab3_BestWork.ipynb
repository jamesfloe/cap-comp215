# %% [markdown]
# <a href="https://colab.research.google.com/github/jamesfloe/cap-comp215/blob/main/Lab3_BestWork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COMP 215 - LAB 3
# ----------------
# #### Name: James Floe
# #### Date: April 11 2022
# This lab exercise is mostly a review of strings, tuples, lists, dictionaries, and functions.
# We will also see how "list comprehension" provides a compact form for "list accumulator" algorithms.
#
# As usual, the first code cell simply imports all the modules we'll be using:
# the json library, which imports methods that manipulate JSON data,
# the requests library which has methods that send HTML requests, and
# the matplotlib.pyplot is a libary of methods which neatly plots data.

# %%
import json, requests 
import matplotlib.pyplot as plt
from pprint import pprint

# %% [markdown]
# We'll answer some questions about movies and TV shows with the IMDb database:  https://www.imdb.com/
# > using the IMDb API:  https://imdb-api.com/api
#
# You can register for your own API key, or simply use the one provided below.
#
# Here's an example query:
#  *   search for TV Series with title == "Lexx"

# %%
API_KEY = 'k_4hstehuv'

title = 'lexx'
url = "https://imdb-api.com/en/API/SearchTitle/{key}/{title}".format(key=API_KEY, title=title)

response = requests.request("GET", url, headers={}, data={}) # requests and gets JSON data from the following API URL.

data = json.loads(response.text)  # recall json.loads for lab 1

results = data['results']
pprint(results)
# Out:
# {'errorMessage': '',
#  'expression': 'lexx',
#  'results': [{'description': '(1996) (TV Series)',
#               'id': 'tt0115243',
#               'image': 'https://imdb-api.com/images/original/MV5BOGFjMzQyMTYtMjQxNy00NjAyLWI2OWMtZGVhMjk4OGM3ZjE5XkEyXkFqcGdeQXVyNzMzMjU5NDY@._V1_Ratio0.7273_AL_.jpg',
#               'resultType': 'Title',
#               'title': 'Lexx'},
#              {'description': '(2008) (Video)',
#               'id': 'tt1833738',
#               'image': 'https://imdb-api.com/images/original/MV5BMjAyMTYzNjk4NV5BMl5BanBnXkFtZTcwNzE4MTU0NA@@._V1_Ratio0.7273_AL_.jpg',
#               'resultType': 'Title',
#               'title': 'Lexx'},
#              {'description': '(2018)',
#               'id': 'tt10800568',
#               'image': 'https://imdb-api.com/images/original/MV5BZWY5ODYwNzYtMmIyMS00YzhhLTg0OTAtODM1M2I5YzkxMzY1XkEyXkFqcGdeQXVyMTEwNDU1MzEy._V1_Ratio0.7273_AL_.jpg',
#               'resultType': 'Title',
#               'title': 'Lexxy Roxx: Lexy 360 - Der Film'},
#              {'description': '(2014) (Short)',
#               'id': 'tt4396272',
#               'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#               'resultType': 'Title',
#               'title': 'Lexxxus'},
#              {'description': '(2016) (Video) aka "Lexxzibé Inonime Nirek & '
#                              'Elmaniak: La Belle Et La Bête (2016)"',
#               'id': 'tt14690226',
#               'image': 'https://imdb-api.com/images/original/MV5BN2NmNGYxZTgtYjg3MC00ZDZhLTk1ODUtM2E4NGYwYzQ3YTFiXkEyXkFqcGdeQXVyMTA2NzA1NDYz._V1_Ratio1.7727_AL_.jpg',
#               'resultType': 'Title',
#               'title': 'Mauvais augure feat. Nirek & Ced (Elmaniak) Auger: La '
#                        'Belle Et La Bête'},
#              {'description': '(2018) (Short)',
#               'id': 'tt12646262',
#               'image': 'https://imdb-api.com/images/original/MV5BODczYTEwNTctYzAzYy00YjIzLThkNGQtMDdjYmU5NjI1MzAxXkEyXkFqcGdeQXVyMTIwNjM2NTQz._V1_Ratio2.3182_AL_.jpg',
#               'resultType': 'Title',
#               'title': 'Lexxe - Red Velvet'},
#              {'description': '(2015)',
#               'id': 'tt2268016',
#               'image': 'https://imdb-api.com/images/original/MV5BNDMyODU3ODk3Ml5BMl5BanBnXkFtZTgwNDc1ODkwNjE@._V1_Ratio0.7273_AL_.jpg',
#               'resultType': 'Title',
#               'title': 'Magic Mike XXL'},
#              {'description': '(2004)',
#               'id': 'tt0346491',
#               'image': 'https://imdb-api.com/images/original/MV5BMTA1NDQ3OTY2NDVeQTJeQWpwZ15BbWU3MDI5MDc0MzM@._V1_Ratio0.7273_AL_.jpg',
#               'resultType': 'Title',
#               'title': 'Alexander'},
#              {'description': '(2020) (TV Series)',
#               'id': 'tt6964748',
#               'image': 'https://imdb-api.com/images/original/MV5BOTg4ZmQ5ZjItZTllZC00NzUzLTkwMTEtMjIzYzliZjk2ODUwXkEyXkFqcGdeQXVyMTEyMjM2NDc2._V1_Ratio0.7273_AL_.jpg',
#               'resultType': 'Title',
#               'title': 'Alex Rider'}],
#  'searchType': 'Title'}

# %% [markdown]
# Next we extract the item we want from the data set by applying a "filter":

# %%
items = [item for item in results if item['title']=='Lexx' and "TV" in item['description']]
assert len(items) == 1
lexx = items[0]
pprint(lexx)
# Out:
# {'description': '(1996) (TV Series)',
#  'id': 'tt0115243',
#  'image': 'https://imdb-api.com/images/original/MV5BOGFjMzQyMTYtMjQxNy00NjAyLWI2OWMtZGVhMjk4OGM3ZjE5XkEyXkFqcGdeQXVyNzMzMjU5NDY@._V1_Ratio0.7273_AL_.jpg',
#  'resultType': 'Title',
#  'title': 'Lexx'}

# %% [markdown]
# ## Exercise 1
#
# In the code cell below, re-write the "list comprehension" above as a loop so you understand how it works.
# Notice how the "conditional list comprehension" is a compact way to "filter" items of interest from a large data set.

# %%
items = []

for item in results:
  if item['title']=='Lexx' and 'TV' in item['description']:
    items.append(item)

lexx = items[0]

pprint(lexx)
# Out:
# {'description': '(1996) (TV Series)',
#  'id': 'tt0115243',
#  'image': 'https://imdb-api.com/images/original/MV5BOGFjMzQyMTYtMjQxNy00NjAyLWI2OWMtZGVhMjk4OGM3ZjE5XkEyXkFqcGdeQXVyNzMzMjU5NDY@._V1_Ratio0.7273_AL_.jpg',
#  'resultType': 'Title',
#  'title': 'Lexx'}

# %% [markdown]
# Notice that the `lexx` dictionary contains an `id` field that uniquely identifies this record in the database.
#
# We can use the `id` to fetch other information about the TV series, for example,
# *   get names of all actors in the TV Series Lexx

# %%
url = "https://imdb-api.com/en/API/FullCast/{key}/{id}".format(key=API_KEY, id=lexx['id'])
response = requests.request("GET", url, headers={}, data={})
data = json.loads(response.text)

actors = data['actors']
pprint(actors[:10])   # recall the slice operator (it's a long list!)
# Out:
# {'actors': [{'asCharacter': 'Stanley H. Tweedle / ... 61 episodes, 1996-2002',
#              'id': 'nm0235978',
#              'image': 'https://imdb-api.com/images/original/MV5BMTYxODI3OTM5Ml5BMl5BanBnXkFtZTgwMjM4ODc3MjE@._V1_Ratio1.3182_AL_.jpg',
#              'name': 'Brian Downey'},
#             {'asCharacter': 'Kai / ... 61 episodes, 1996-2002',
#              'id': 'nm0573158',
#              'image': 'https://imdb-api.com/images/original/MV5BMTY3MjQ4NzE0NV5BMl5BanBnXkFtZTgwNDE4ODc3MjE@._V1_Ratio1.3182_AL_.jpg',
#              'name': 'Michael McManus'},
#             {'asCharacter': '790 / ... 57 episodes, 1996-2002',
#              'id': 'nm0386601',
#              'image': 'https://imdb-api.com/images/original/MV5BMjMyMDM1NzgzNF5BMl5BanBnXkFtZTgwOTM4ODc3MjE@._V1_Ratio1.3182_AL_.jpg',
#              'name': 'Jeffrey Hirschfield'},
#             {'asCharacter': 'Xev Bellringer / ... 55 episodes, 1998-2002',
#              'id': 'nm0781462',
#              'image': 'https://imdb-api.com/images/original/MV5BMTk2MDQ4NzExOF5BMl5BanBnXkFtZTcwOTMyNzcyMQ@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Xenia Seeberg'},
#             {'asCharacter': 'The Lexx 46 episodes, 1996-2002',
#              'id': 'nm0302577',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Tom Gallant'},
#             {'asCharacter': 'Prince / ... 23 episodes, 2000-2002',
#              'id': 'nm0000911',
#              'image': 'https://imdb-api.com/images/original/MV5BMTgxMTY2NzM5NF5BMl5BanBnXkFtZTcwMDA5MDYxOA@@._V1_Ratio0.7727_AL_.jpg',
#              'name': 'Nigel Bennett'},
#             {'asCharacter': 'Bunny Priest / ... 16 episodes, 1999-2002',
#              'id': 'nm0954934',
#              'image': 'https://imdb-api.com/images/original/MV5BMTg2Mjk2Nzk5NV5BMl5BanBnXkFtZTcwNzYyODQzMQ@@._V1_Ratio0.7727_AL_.jpg',
#              'name': 'Patricia Zentilli'},
#             {'asCharacter': 'Bound Man / ... 8 episodes, 1996-2002',
#              'id': 'nm0317596',
#              'image': 'https://imdb-api.com/images/original/MV5BNjNiNzAwMjQtYTU1NC00NDkzLWI4OTktYjA0NWRiZjEzZmFkXkEyXkFqcGdeQXVyMTAwMzUyMzUy._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Lex Gigeroff'},
#             {'asCharacter': 'Reginald J. Priest / ... 13 episodes, 2000-2002',
#              'id': 'nm0437708',
#              'image': 'https://imdb-api.com/images/original/MV5BMWFmNDI5YWEtMjRkYi00MTRhLTk5YjMtYTEwNTgyMWQ2ODk4XkEyXkFqcGdeQXVyNDM4NDA1Mg@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Rolf Kanies'},
#             {'asCharacter': 'Lyekka / ... 10 episodes, 1998-2002',
#              'id': 'nm0936263',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Louise Wischermann'},
#             {'asCharacter': 'Divine Predecessor / ... 7 episodes, 1996-2002',
#              'id': 'nm0243082',
#              'image': 'https://imdb-api.com/images/original/MV5BMTc0MzA1NTExMl5BMl5BanBnXkFtZTcwMzU5NTgwOA@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'John Dunsworth'},
#             {'asCharacter': 'His Divine Shadow / ... 8 episodes, 1996-2002',
#              'id': 'nm0096168',
#              'image': 'https://imdb-api.com/images/original/MV5BMTI4NDQ2NzI0OF5BMl5BanBnXkFtZTcwMTM3MDkyMQ@@._V1_Ratio0.7727_AL_.jpg',
#              'name': 'Walter Borden'},
#             {'asCharacter': 'Mothbreeder / ... 3 episodes, 1998-2002',
#              'id': 'nm1116337',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'David Albiston'},
#             {'asCharacter': 'Vlad / ... 5 episodes, 2001-2002',
#              'id': 'nm0007392',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Minna Aaltonen'},
#             {'asCharacter': 'Megashadow Adjutant / ... 6 episodes, 1996-2000',
#              'id': 'nm0842105',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Clive Sweeney'},
#             {'asCharacter': 'Zev Bellringer 7 episodes, 1996-2000',
#              'id': 'nm0352230',
#              'image': 'https://imdb-api.com/images/original/MV5BNWU1MzZjZmYtYzkyOC00OGQ2LWI1ZWYtMzdkODgzNGYzNjU4XkEyXkFqcGdeQXVyMjM1OTk0NDQ@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Eva Habermann'},
#             {'asCharacter': 'Giggerota / ... 7 episodes, 1996-2002',
#              'id': 'nm0239294',
#              'image': 'https://imdb-api.com/images/original/MV5BYTMxOGRjMDEtZTkxMC00NWEyLTg2YjYtMjMzNmJiZmIzODcwXkEyXkFqcGdeQXVyMDYxMjk5MQ@@._V1_Ratio1.5000_AL_.jpg',
#              'name': 'Ellen Dubin'},
#             {'asCharacter': 'The Time Prophet / ... 5 episodes, 1996-2002',
#              'id': 'nm0131487',
#              'image': 'https://imdb-api.com/images/original/MV5BMjAyNzU1MTQyM15BMl5BanBnXkFtZTgwMDg4ODc3MjE@._V1_Ratio1.3182_AL_.jpg',
#              'name': 'Anna Cameron'},
#             {'asCharacter': 'Mantrid 5 episodes, 1998-2000',
#              'id': 'nm0489504',
#              'image': 'https://imdb-api.com/images/original/MV5BMjg1NWQ2ZTItMTU4MS00YTkyLWI1MzEtY2EzYTVlNDA1MmFjXkEyXkFqcGdeQXVyMTI3MDk3MzQ@._V1_Ratio1.6364_AL_.jpg',
#              'name': 'Dieter Laser'},
#             {'asCharacter': 'Fifi / ... 6 episodes, 1999-2001',
#              'id': 'nm0701146',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Jeff Pustil'},
#             {'asCharacter': 'Holo Cleric / ... 5 episodes, 1996-2001',
#              'id': 'nm0565774',
#              'image': 'https://imdb-api.com/images/original/MV5BNzhhYTNlNjQtNTc0NC00NGY3LTk1NTEtMGM0Njk2ZTJmOWRmXkEyXkFqcGdeQXVyMjM2ODExMQ@@._V1_Ratio0.7727_AL_.jpg',
#              'name': 'David McClelland'},
#             {'asCharacter': 'Dougall 4 episodes, 2001-2002',
#              'id': 'nm2624364',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Kevin Curran'},
#             {'asCharacter': 'Jood / ... 5 episodes, 1996-2001',
#              'id': 'nm0103267',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Jamie Bradley'},
#             {'asCharacter': 'Transport Major / ... 5 episodes, 1996-1999',
#              'id': 'nm0015193',
#              'image': 'https://imdb-api.com/images/original/MV5BMTA4MjQ1NzQ1ODheQTJeQWpwZ15BbWU3MDQ5ODI4MzI@._V1_Ratio1.0909_AL_.jpg',
#              'name': 'Jeremy Akerman'},
#             {'asCharacter': 'Child / ... 5 episodes, 1996-1999',
#              'id': 'nm0037627',
#              'image': 'https://imdb-api.com/images/original/MV5BMWZlYTM1NjctM2VjZi00NmM5LTgyOTEtM2E4OWJhNzk0NmY1XkEyXkFqcGdeQXVyMzU3NTAyNzQ@._V1_Ratio1.5000_AL_.jpg',
#              'name': 'Nicolás Artajo'},
#             {'asCharacter': 'Holo Lawyr / ... 5 episodes, 1996-2002',
#              'id': 'nm0201766',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'John Dartt'},
#             {'asCharacter': 'Video Customs Officer / ... 5 episodes, 1996-2001',
#              'id': 'nm0493351',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Chas Lawther'},
#             {'asCharacter': 'Mothbreeder / ... 1 episode, 2000-2002',
#              'id': 'nm2067344',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Todd Godin'},
#             {'asCharacter': 'Petrif / ... 4 episodes, 1996-2000',
#              'id': 'nm0797459',
#              'image': 'https://imdb-api.com/images/original/MV5BMTU0MTE3NDc3MV5BMl5BanBnXkFtZTYwNDQxMjEz._V1_Ratio1.4091_AL_.jpg',
#              'name': 'Robert Sigl'},
#             {'asCharacter': 'Joshua / ... 4 episodes, 1996-2000',
#              'id': 'nm0719881',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'David Renton'},
#             {'asCharacter': 'Holo Judge / ... 4 episodes, 1996-1999',
#              'id': 'nm0234734',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Lionel Doucette'},
#             {'asCharacter': 'Duke 5 episodes, 2000',
#              'id': 'nm0114460',
#              'image': 'https://imdb-api.com/images/original/MV5BMTQ5MDQ3ODY3N15BMl5BanBnXkFtZTcwNDEzNDc3Mg@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Ralph Brown'},
#             {'asCharacter': 'May 5 episodes, 2000',
#              'id': 'nm0088304',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Anna Kathrin Bleuler'},
#             {'asCharacter': 'Anchorman / ... 4 episodes, 2001-2002',
#              'id': 'nm0030022',
#              'image': 'https://imdb-api.com/images/original/MV5BOTYyMjY2NTE4MF5BMl5BanBnXkFtZTgwNzYyNTM0MjE@._V1_Ratio1.3182_AL_.jpg',
#              'name': 'Tony Anholt'},
#             {'asCharacter': 'Tina 4 episodes, 2001-2002',
#              'id': 'nm0236502',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Tara Doyle'},
#             {'asCharacter': 'Lead Balloonist / ... 4 episodes, 2000-2002',
#              'id': 'nm1022857',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Gary Levert'},
#             {'asCharacter': 'Handler 2 / ... 4 episodes, 1999-2001',
#              'id': 'nm0522630',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Jon K. Loverin'},
#             {'asCharacter': 'Archaeologist / ... 4 episodes, 1996-2002',
#              'id': 'nm0905599',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Glenn Wadman'},
#             {'asCharacter': 'Matron / ... 3 episodes, 1997-2000',
#              'id': 'nm0653946',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Jennifer Overton'},
#             {'asCharacter': 'Brock / ... 3 episodes, 2000-2001',
#              'id': 'nm0380189',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Geoff Herod'},
#             {'asCharacter': 'Blue Team Member / ... 1 episode, 2000-2002',
#              'id': 'nm0335418',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Glen Grant'},
#             {'asCharacter': 'Megashadow Admiral 4 episodes, 1996-1997',
#              'id': 'nm0232195',
#              'image': 'https://imdb-api.com/images/original/MV5BMjMxODkxMDgzMV5BMl5BanBnXkFtZTgwNjU5MDg5MjE@._V1_Ratio1.3182_AL_.jpg',
#              'name': 'Richard Donat'},
#             {'asCharacter': 'Tem 4 episodes, 1996-1997',
#              'id': 'nm0107621',
#              'image': 'https://imdb-api.com/images/original/MV5BOWM1NTRhMDktMjE0ZS00NGYzLTg2OGItY2JjMzJiY2ZmNWE2XkEyXkFqcGdeQXVyOTY5NjI2Mg@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Gil Brenton'},
#             {'asCharacter': 'Wig Girl 4 episodes, 1996-1997',
#              'id': 'nm1683263',
#              'image': 'https://imdb-api.com/images/original/MV5BMTIwNzY2MjEyMF5BMl5BanBnXkFtZTcwOTY5MzgyMQ@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Barbara Kowa'},
#             {'asCharacter': 'Correction Center Guard 4 episodes, 1996-1997',
#              'id': 'nm0139610',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Bill Carr'},
#             {'asCharacter': 'Honar 4 episodes, 1996-1997',
#              'id': 'nm0848345',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Sanjay Talwar'},
#             {'asCharacter': 'Monk 4 episodes, 1996-1997',
#              'id': 'nm2675156',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Clemens von Tubeuf'},
#             {'asCharacter': 'Scientist 4 episodes, 1996-1997',
#              'id': 'nm0002268',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Gary Vermeir'},
#             {'asCharacter': 'Cluster Major 4 episodes, 1996-1997',
#              'id': 'nm0192345',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Jocelyn Cunningham'},
#             {'asCharacter': 'Rebel 4 episodes, 1996-1997',
#              'id': 'nm0536763',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Andrei Mahankov'},
#             {'asCharacter': 'E.J. Moss, Commander of Eagle 5 / ... 3 episodes, '
#                             '1998-2002',
#              'id': 'nm0565569',
#              'image': 'https://imdb-api.com/images/original/MV5BMGNlY2U5YmQtMjVmZi00N2ZiLWEwODktODA3YTViNjRhYzIxXkEyXkFqcGdeQXVyNjUxMjc1OTM@._V1_Ratio2.4091_AL_.jpg',
#              'name': 'Stephen McHattie'},
#             {'asCharacter': 'Digby 3 episodes, 2001',
#              'id': 'nm0177620',
#              'image': 'https://imdb-api.com/images/original/MV5BMTk1OTcxOTc2OF5BMl5BanBnXkFtZTYwNjYxOTY0._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Ryan Cooley'},
#             {'asCharacter': 'Big Angry Ed / ... 3 episodes, 1999-2001',
#              'id': 'nm1051853',
#              'image': 'https://imdb-api.com/images/original/MV5BZjQ4Mzc2OTEtNGQ0Ni00NWU2LWEwZDQtOGMyYWNjZTY3YTZiXkEyXkFqcGdeQXVyMTA4MjY5OQ@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Mark A. Owen'},
#             {'asCharacter': 'First Lady Priest / ... 2 episodes, 1999-2001',
#              'id': 'nm0942476',
#              'image': 'https://imdb-api.com/images/original/MV5BMGE1ZTMzMWItZTAwMS00N2I3LThlMTktN2U0ZWQ2NTUyYzA3L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTExNDQ2MTI@._V1_Ratio1.0909_AL_.jpg',
#              'name': 'Janet Wright'},
#             {'asCharacter': 'Moth Breeder / ... 2 episodes, 2001-2002',
#              'id': 'nm0564301',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Geoff McBride'},
#             {'asCharacter': 'Moth Breeder 2 episodes, 2001-2002',
#              'id': 'nm3579176',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Jenson Vaughan'},
#             {'asCharacter': 'Louie / ... 2 episodes, 1999-2002',
#              'id': 'nm0215581',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Louis Del Grande'},
#             {'asCharacter': 'Norb / ... 2 episodes, 1999',
#              'id': 'nm0565443',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Brandon McCarvell'},
#             {'asCharacter': 'Boork / ... 2 episodes, 1997-1998',
#              'id': 'nm0475202',
#              'image': 'https://imdb-api.com/images/original/MV5BMDcwNzViMDYtN2JhMy00MGNjLTkyMTMtNTViNzBlZjIwZDM3XkEyXkFqcGdeQXVyMTAwMzUyMzUy._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Holger Kunkel'},
#             {'asCharacter': 'Davinia Silver / ... 2 episodes, 2001',
#              'id': 'nm1605007',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Andrea Green'},
#             {'asCharacter': 'Lomea / ... 2 episodes, 1999-2001',
#              'id': 'nm1036268',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Lauren Abrahams'},
#             {'asCharacter': '791 / ... 2 episodes, 1999-2002',
#              'id': 'nm0141499',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Brian Carter'},
#             {'asCharacter': 'Chief Handler 2 episodes, 2000',
#              'id': 'nm0123906',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Linda Busby'},
#             {'asCharacter': 'Joseph Van Helsing 2 episodes, 2001',
#              'id': 'nm0347423',
#              'image': 'https://imdb-api.com/images/original/MV5BMTU2Mjc3NDQxNF5BMl5BanBnXkFtZTgwMzQzNzg5NDE@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Peter Guinness'},
#             {'asCharacter': 'Dad / ... 2 episodes, 2001',
#              'id': 'nm0167706',
#              'image': 'https://imdb-api.com/images/original/MV5BMTc2NTAxMTI1NV5BMl5BanBnXkFtZTYwNTgyMTEz._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Stephen Coats'},
#             {'asCharacter': 'Muffy / ... 2 episodes, 2001',
#              'id': 'nm0003723',
#              'image': 'https://imdb-api.com/images/original/MV5BMTc4NTYwODcxNF5BMl5BanBnXkFtZTYwMjk0OTcy._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Angie Hill'},
#             {'asCharacter': 'Gordon 2 episodes, 2002',
#              'id': 'nm0292744',
#              'image': 'https://imdb-api.com/images/original/MV5BYWEwM2M1YzItNTkzNi00MDMyLWIzNDMtMGZiZDI2YWM4YTMzXkEyXkFqcGdeQXVyNDkzNDM2OA@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Dan Fredenburgh'},
#             {'asCharacter': 'Dream Girl #2 / ... 2 episodes, 1999',
#              'id': 'nm1581443',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Laura Mae Nason'},
#             {'asCharacter': 'ATF Agent #1 / ... 2 episodes, 1998-2001',
#              'id': 'nm1254005',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Chris Duffy'},
#             {'asCharacter': 'Skankita 2 episodes, 2002',
#              'id': 'nm1131152',
#              'image': 'https://imdb-api.com/images/original/MV5BNTIxY2MzZWEtYWUxNC00NjI5LTg5NjAtYjAzNGYzNzU1OTljXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Marem Hassler'},
#             {'asCharacter': 'Road Worker / ... 2 episodes, 1999-2002',
#              'id': 'nm0671066',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Michael Pellerin'},
#             {'asCharacter': 'Root / ... 2 episodes, 2000-2002',
#              'id': 'nm0134227',
#              'image': 'https://imdb-api.com/images/original/MV5BM2QwYjZjYmYtZTNmYi00NTYzLTlmZTUtZTRjZjk0OTY2ZjEwXkEyXkFqcGdeQXVyMTAwMjQ1OTU@._V1_Ratio1.5000_AL_.jpg',
#              'name': 'Landy Cannon'},
#             {'asCharacter': 'Mandragora Morgana / ... 2 episodes, 2001',
#              'id': 'nm2094983',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Rachel Mooney'},
#             {'asCharacter': 'Flintokk, Head Pimp Sister / ... 2 episodes, '
#                             '1999-2000',
#              'id': 'nm0803016',
#              'image': 'https://imdb-api.com/images/original/MV5BMTc4MTcwNDEwN15BMl5BanBnXkFtZTcwNjk5NTIzMQ@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Stephen J.M. Sisk'},
#             {'asCharacter': 'Doily / ... 2 episodes, 1999-2000',
#              'id': 'nm2078873',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Andre Haines'},
#             {'asCharacter': 'Argon Protopi / ... 2 episodes, 1996-1999',
#              'id': 'nm0532262',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Alan MacGillivray'},
#             {'asCharacter': 'Reteep / ... 2 episodes, 1997',
#              'id': 'nm0164996',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Shaun Clarke'},
#             {'asCharacter': 'Commentator / ... 2 episodes, 2001-2002',
#              'id': 'nm0693788',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Graham Pountney'},
#             {'asCharacter': 'Rexal / ... 2 episodes, 1999-2001',
#              'id': 'nm0925425',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Sam White'},
#             {'asCharacter': 'Eco Tourist #2 / ... 2 episodes, 1999-2001',
#              'id': 'nm0807320',
#              'image': 'https://imdb-api.com/images/original/MV5BOWU4MGY3YWQtNTA0Ni00YjRkLTkwZDQtZDM0NmQ5MTBkOTY2XkEyXkFqcGdeQXVyMTQ5NjcwMQ@@._V1_Ratio1.5000_AL_.jpg',
#              'name': 'Andy Smith'},
#             {'asCharacter': 'Computer / ... 2 episodes, 1999-2001',
#              'id': 'nm1050691',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Angela Vermeir'},
#             {'asCharacter': 'Bellhop / ... 2 episodes, 1996-2002',
#              'id': 'nm2253598',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Jack Carr'},
#             {'asCharacter': 'Middle aged woman / ... 2 episodes, 1999-2001',
#              'id': 'nm0925456',
#              'image': 'https://imdb-api.com/images/original/MV5BMTk1MTE2MjQ0MV5BMl5BanBnXkFtZTgwMTQyNDEwMDI@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Sherry White'},
#             {'asCharacter': '790 Robot / ... 2 episodes, 1996-1997',
#              'id': 'nm0676914',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Mike Petersen'},
#             {'asCharacter': 'Pa Gollean / ... 1 episode, 1999',
#              'id': 'nm0001999',
#              'image': 'https://imdb-api.com/images/original/MV5BMTU2NjA2NDg5Nl5BMl5BanBnXkFtZTcwOTMxNzkyOA@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Maury Chaykin'},
#             {'asCharacter': 'Original Xev / ... 2 episodes, 1996-2000',
#              'id': 'nm0385694',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Lisa Hynes'},
#             {'asCharacter': 'Priest / ... 1 episode, 2000',
#              'id': 'nm0950245',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Malcolm Younger'},
#             {'asCharacter': 'Desh / ... 1 episode, 1999-2002',
#              'id': 'nm0449643',
#              'image': 'https://imdb-api.com/images/original/MV5BMjAxMTY4NDUyOF5BMl5BanBnXkFtZTcwNTUwOTkyMQ@@._V1_Ratio0.7727_AL_.jpg',
#              'name': 'Amy Kerr'},
#             {'asCharacter': 'Peasant 1 episode, 2001',
#              'id': 'nm0375821',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Jeri-Matti Helppi'},
#             {'asCharacter': 'Druid Girl / ... 1 episode, 1999-2001',
#              'id': 'nm1120797',
#              'image': 'https://imdb-api.com/images/original/MV5BZTYzOTE0ODQtY2MxYy00YzZlLTkzNDItY2NmM2VhOGY1M2U2XkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Cindy Sampson'},
#             {'asCharacter': 'Black Pawn #3 / ... 1 episode, 2001-2002',
#              'id': 'nm0949734',
#              'image': 'https://imdb-api.com/images/original/MV5BYTkxZmU4MzMtMTUzMi00MWUzLWFhZWQtMGZlZDk3NjlkNGRmXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Joshua Young'},
#             {'asCharacter': 'C.G. 1 episode, 1999',
#              'id': 'nm0850969',
#              'image': 'https://imdb-api.com/images/original/MV5BMGM2NDA1ZjMtZmZhYS00ZmQwLTgzNjAtNTJlYTdkYTc4NTM0XkEyXkFqcGdeQXVyODQ5NjYzODk@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Tom Tasse'},
#             {'asCharacter': 'Thief / ... 1 episode, 1999-2001',
#              'id': 'nm0924841',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Gordon Patrick White'},
#             {'asCharacter': 'Dr. Kazan 1 episode, 1998',
#              'id': 'nm0508996',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Simon Licht'},
#             {'asCharacter': 'The Dark Lady 1 episode, 1999',
#              'id': 'nm0952801',
#              'image': 'https://imdb-api.com/images/original/MV5BMjE1MDk2NzI1NF5BMl5BanBnXkFtZTcwOTU3ODgyMQ@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Lenore Zann'},
#             {'asCharacter': 'Captain Jebbed 1 episode, 1999',
#              'id': 'nm0282088',
#              'image': 'https://imdb-api.com/images/original/MV5BMjA1NjA5Njc3NF5BMl5BanBnXkFtZTcwODM1Mjg4NA@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Page Fletcher'},
#             {'asCharacter': 'Grand Prosecutor Jihana 1 episode, 1999',
#              'id': 'nm0291711',
#              'image': 'https://imdb-api.com/images/original/MV5BNjAzNDEyNTU2NF5BMl5BanBnXkFtZTcwNjA3NDYxMw@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Nina Franoszek'},
#             {'asCharacter': 'Brizon 1 episode, 1999',
#              'id': 'nm0664387',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Earl Pastko'},
#             {'asCharacter': 'Enox 1 episode, 1999',
#              'id': 'nm0081735',
#              'image': 'https://imdb-api.com/images/original/MV5BODk1NTk5NGItZDNhYi00Nzk1LTgwZmMtNWJjYzYyNjlmNjc2XkEyXkFqcGdeQXVyNDI0NDgzNDk@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Andrew Bigelow'},
#             {'asCharacter': 'Brother Randor 1 episode, 1999',
#              'id': 'nm0123672',
#              'image': 'https://imdb-api.com/images/original/MV5BOGM4ZjMyMTItODQxYi00ZjkyLWJhM2EtMWE0NThmZjEwMTUzXkEyXkFqcGdeQXVyMjg4MDA4Mw@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Matthew Burton'},
#             {'asCharacter': 'Master of Ceremonies 1 episode, 1999',
#              'id': 'nm0916152',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Jeremy Webb'},
#             {'asCharacter': 'Card Carrying Druid 1 episode, 2001',
#              'id': 'nm0104033',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Richard Braine'},
#             {'asCharacter': 'Deputy Festus Trout 1 episode, 2002',
#              'id': 'nm1591420',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Nick Cawdron'},
#             {'asCharacter': 'Poet Man 1 episode, 1997',
#              'id': 'nm0000347',
#              'image': 'https://imdb-api.com/images/original/MV5BMTc5MTQ2OTYwOF5BMl5BanBnXkFtZTYwMzEzMTA1._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Tim Curry'},
#             {'asCharacter': 'Smoor 1 episode, 1997',
#              'id': 'nm0427480',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Andy Jones'},
#             {'asCharacter': 'Gubby Mok 1 episode, 1999',
#              'id': 'nm0733500',
#              'image': 'https://imdb-api.com/images/original/MV5BMTk5NjgyNTAzMV5BMl5BanBnXkFtZTcwNzIwOTgxOA@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Wayne Robson'},
#             {'asCharacter': 'Heedia 1 episode, 1999',
#              'id': 'nm0909763',
#              'image': 'https://imdb-api.com/images/original/MV5BMTQzNTM1Njc5OV5BMl5BanBnXkFtZTYwMTExMzk1._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Mary Walsh'},
#             {'asCharacter': 'Tad 1 episode, 1999',
#              'id': 'nm0124089',
#              'image': 'https://imdb-api.com/images/original/MV5BMTkzODA4NDQ4Ml5BMl5BanBnXkFtZTcwMjI3MDkyMQ@@._V1_Ratio0.9091_AL_.jpg',
#              'name': 'Andrew Bush'},
#             {'asCharacter': 'Sissy Gollean 1 episode, 1999',
#              'id': 'nm0198359',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Susan Quinn'},
#             {'asCharacter': 'Aulk 1 episode, 1999',
#              'id': 'nm0150315',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Diego Chambers'},
#             {'asCharacter': 'Brother Treygor 1 episode, 1999',
#              'id': 'nm0459570',
#              'image': 'https://imdb-api.com/images/original/MV5BMzU3NGI0ZWMtZDQxNS00YmNmLWI3N2QtYWYxYTAzYzk1YWExXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_Ratio1.3182_AL_.jpg',
#              'name': 'Matthias Klimsa'},
#             {'asCharacter': 'Slinka 1 episode, 1999',
#              'id': 'nm2333298',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Barbara Schmied'},
#             {'asCharacter': 'Rivet 1 episode, 2000',
#              'id': 'nm0687084',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Polly Jo Pleasence'},
#             {'asCharacter': 'Lily 1 episode, 2000',
#              'id': 'nm0351742',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Julia Haacke'},
#             {'asCharacter': 'Cellphone Druid 1 episode, 2001',
#              'id': 'nm0160484',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'David Christoffel'},
#             {'asCharacter': 'Dulcibella Sternflanks 1 episode, 2002',
#              'id': 'nm0001180',
#              'image': 'https://imdb-api.com/images/original/MV5BMjEyMTQ5NTE2M15BMl5BanBnXkFtZTYwNTc2NTI2._V1_Ratio0.7727_AL_.jpg',
#              'name': 'Britt Ekland'},
#             {'asCharacter': 'Amber 1 episode, 2002',
#              'id': 'nm1153173',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Polly Green'},
#             {'asCharacter': 'Bereaved Mom 1 episode, 2002',
#              'id': 'nm1102594',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Kathryn Fraser'},
#             {'asCharacter': 'Nurse / ... 1 episode, 1999',
#              'id': 'nm0445757',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Sandra Keller'},
#             {'asCharacter': 'Junior Gollean 1 episode, 1999',
#              'id': 'nm2087640',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Dave Carmichael'},
#             {'asCharacter': 'Groo 1 episode, 1999',
#              'id': 'nm2057642',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Sharon Timmins'},
#             {'asCharacter': 'Tish 1 episode, 2000',
#              'id': 'nm0503011',
#              'image': 'https://imdb-api.com/images/original/MV5BYmRhYTBlZGQtNTA3NS00ZjRhLWIwODctMWUyOTA1ZjdiMTY2XkEyXkFqcGdeQXVyMTAwMzUyMzUy._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Sandra S. Leonhard'},
#             {'asCharacter': 'Wench 1 episode, 2000',
#              'id': 'nm0623818',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Terry Neason'},
#             {'asCharacter': 'Tulip 1 episode, 2000',
#              'id': 'nm1066713',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Hephzibah Tintner'},
#             {'asCharacter': 'Minx 1 episode, 2000',
#              'id': 'nm2070970',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Nicole Ciroth'},
#             {'asCharacter': 'Colin 1 episode, 2001',
#              'id': 'nm0263854',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Nick Ewans'},
#             {'asCharacter': 'Merle 1 episode, 2001',
#              'id': 'nm2075949',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Michael Best'},
#             {'asCharacter': 'Didi Figgleshrick 1 episode, 2002',
#              'id': 'nm1292663',
#              'image': 'https://imdb-api.com/images/original/MV5BZjZjY2YwYmMtZTNiZi00MTA3LThhZDAtZjA5MjRhZGIyN2RkXkEyXkFqcGdeQXVyNTAzNzE4NTQ@._V1_Ratio0.7727_AL_.jpg',
#              'name': 'Celia Henebury'},
#             {'asCharacter': 'Wyatt 1 episode, 2002',
#              'id': 'nm1357378',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Mason Phillips'},
#             {'asCharacter': 'FBI Lieutenant 1 episode, 2002',
#              'id': 'nm1472220',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Donald Chisholm'},
#             {'asCharacter': 'Thodin 1 episode, 1996',
#              'id': 'nm0000960',
#              'image': 'https://imdb-api.com/images/original/MV5BOTQ1Mzc4YjQtY2RlMC00ZjNiLWE5NmMtZDlhYzkyOGI1MWNmXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_Ratio0.8182_AL_.jpg',
#              'name': 'Barry Bostwick'},
#             {'asCharacter': 'Yottskry 1 episode, 1997',
#              'id': 'nm0000532',
#              'image': 'https://imdb-api.com/images/original/MV5BMTcxMjQxNzczM15BMl5BanBnXkFtZTcwMTg3MTMwNw@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Malcolm McDowell'},
#             {'asCharacter': 'Snik 1 episode, 1997',
#              'id': 'nm0937760',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Gerry Wolff'},
#             {'asCharacter': 'Holo Woman 1 episode, 1997',
#              'id': 'nm3055126',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Kate Rose'},
#             {'asCharacter': 'L.L. Boosh 1 episode, 1998',
#              'id': 'nm0687999',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Roman Podhora'},
#             {'asCharacter': 'Dr. Funz 1 episode, 1998',
#              'id': 'nm0827811',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Oliver Stern'},
#             {'asCharacter': 'Nool 1 episode, 1999',
#              'id': 'nm0755518',
#              'image': 'https://imdb-api.com/images/original/MV5BOTE1OTMwMzgyOF5BMl5BanBnXkFtZTcwMTQzMzIwNQ@@._V1_Ratio1.5000_AL_.jpg',
#              'name': 'Benjamin Sadler'},
#             {'asCharacter': 'Rissha 1 episode, 1999',
#              'id': 'nm0377286',
#              'image': 'https://imdb-api.com/images/original/MV5BMzFkOTRhN2UtNjBiMS00OWMwLWEyNTEtNGI4MmRhMWUxNDc0XkEyXkFqcGdeQXVyMzM4MjM0Nzg@._V1_Ratio0.7727_AL_.jpg',
#              'name': 'Ellen-Ray Hennessy'},
#             {'asCharacter': 'Kanana 1 episode, 1999',
#              'id': 'nm0055955',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Nikki Barnett'},
#             {'asCharacter': 'Skye 1 episode, 1999',
#              'id': 'nm0574242',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Kerry McPherson'},
#             {'asCharacter': 'Kyoo 1 episode, 1999',
#              'id': 'nm1635103',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Paul McQuillan'},
#             {'asCharacter': 'Hammer 1 episode, 2000',
#              'id': 'nm0486734',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Diane Langton'},
#             {'asCharacter': 'Cab 1 episode, 2000',
#              'id': 'nm0719013',
#              'image': 'https://imdb-api.com/images/original/MV5BMDBhNDVlZGYtMzYxOS00MTkwLWIxZTAtZGQyMTA2ZmZkNjFlXkEyXkFqcGdeQXVyMjA2ODMxMTc@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Urs Remond'},
#             {'asCharacter': 'Dr. Bunz 1 episode, 2000',
#              'id': 'nm0427226',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Udo Jolly'},
#             {'asCharacter': 'Daisy 1 episode, 2000',
#              'id': 'nm0711890',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Sabrina Rattey'},
#             {'asCharacter': 'Oliver 1 episode, 2001',
#              'id': 'nm0086691',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Peter Blake'},
#             {'asCharacter': 'Puck 1 episode, 2001',
#              'id': 'nm0290344',
#              'image': 'https://imdb-api.com/images/original/MV5BZTBjNjU1YmQtNmY2NS00MmM3LWIwMjUtNmVhMDc5YzQxMDcyXkEyXkFqcGdeQXVyNTEzNTE1Njc@._V1_Ratio0.7727_AL_.jpg',
#              'name': 'Tim Frances'},
#             {'asCharacter': 'Executive 1 episode, 2001',
#              'id': 'nm0041033',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Howard Attfield'},
#             {'asCharacter': 'Native American Leader 1 episode, 2001',
#              'id': 'nm1797077',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Agumeuay Nakanakis'},
#             {'asCharacter': 'Tourist 1 episode, 2001',
#              'id': 'nm2102947',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Danielle Dawe'},
#             {'asCharacter': 'Older Woman 1 episode, 2001',
#              'id': 'nm1083224',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Lois Brown'},
#             {'asCharacter': 'Josh 1 episode, 2002',
#              'id': 'nm1276440',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Johnny Lomas'},
#             {'asCharacter': 'Queen of Sheba 1 episode, 2002',
#              'id': 'nm1322299',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Andrulla Blanchette'},
#             {'asCharacter': 'Burl 1 episode, 2002',
#              'id': 'nm0970833',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'John Diamond'},
#             {'asCharacter': "Zev's Mother 1 episode, 1997",
#              'id': 'nm2287155',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Rachel Grover'},
#             {'asCharacter': 'Dr. Veezra 1 episode, 1998',
#              'id': 'nm0311888',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Barbara Geiger'},
#             {'asCharacter': 'Fruitcake 1 episode, 1999-2000',
#              'id': 'nm0416404',
#              'image': 'https://imdb-api.com/images/original/MV5BNjBiMzkxYTktNTFkYS00MTI1LThjZGQtZWYzYmJjNmExMzM3XkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'David Lewis'},
#             {'asCharacter': 'Calico 1 episode, 1999',
#              'id': 'nm0809998',
#              'image': 'https://imdb-api.com/images/original/MV5BMDY1ZTllZDUtMGNmYi00N2NkLWI5M2MtOGUxMDNmYzJiZjQxXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Stacy Smith'},
#             {'asCharacter': 'Lissha 1 episode, 1999',
#              'id': 'nm3141671',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Susanna Metzner'},
#             {'asCharacter': 'Older Brother 1 episode, 1999',
#              'id': 'nm0405949',
#              'image': 'https://imdb-api.com/images/original/MV5BNmU1YzU0MzEtNzEzZi00ODI0LWI3ODktOTg2YmVjMTliY2Y3XkEyXkFqcGdeQXVyMjg4MDA4Mw@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Martin Höner'},
#             {'asCharacter': 'Gibble 1 episode, 1999',
#              'id': 'nm0277235',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Bruce Fillmore'},
#             {'asCharacter': 'New Born 1 episode, 1999',
#              'id': 'nm2050293',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Joe Wynn'},
#             {'asCharacter': 'Daffodil 1 episode, 2000',
#              'id': 'nm0459819',
#              'image': 'https://imdb-api.com/images/original/MV5BZGQ4NDA5MGEtN2RhYy00YzI4LTllOWEtMjFiNWNlZjQ5MWU2XkEyXkFqcGdeQXVyMTA1MDM4Mjk1._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Ina Paule Klink'},
#             {'asCharacter': 'Socket 1 episode, 2000',
#              'id': 'nm0119007',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Jelena Budimir'},
#             {'asCharacter': 'Zin 1 episode, 2000',
#              'id': 'nm1558070',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Hans Brückner'},
#             {'asCharacter': 'Fox 1 episode, 2000',
#              'id': 'nm1221774',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Katrin Schrake'},
#             {'asCharacter': 'The Warden 1 episode, 2001',
#              'id': 'nm0153002',
#              'image': 'https://imdb-api.com/images/original/MV5BMjI0ODI3MzY0N15BMl5BanBnXkFtZTcwODE1MzIyOA@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Craig Charles'},
#             {'asCharacter': 'Vet 1 episode, 2001',
#              'id': 'nm0070779',
#              'image': 'https://imdb-api.com/images/original/MV5BMTg0NzkyMTIyM15BMl5BanBnXkFtZTgwMDk3NDQ5ODE@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Jay Benedict'},
#             {'asCharacter': 'George 1 episode, 2001',
#              'id': 'nm1896146',
#              'image': 'https://imdb-api.com/images/original/MV5BMjkwZDAwMDYtZTg3NS00Yzk4LWE0MDMtYTBhM2U1ZjgzNzhjXkEyXkFqcGdeQXVyMzQ0MjcxNTQ@._V1_Ratio1.5000_AL_.jpg',
#              'name': 'Brian Buckley'},
#             {'asCharacter': 'Mustafa Al Hambra 1 episode, 2001',
#              'id': 'nm0175773',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Alexis Conran'},
#             {'asCharacter': 'Dale 1 episode, 2001',
#              'id': 'nm2076074',
#              'image': 'https://imdb-api.com/images/original/MV5BOGYxYjZlYzQtZDc3ZS00YzU1LWE0ZTYtODYxMzZhY2ZhZjEwXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Bob Dearden'},
#             {'asCharacter': 'Oberon 1 episode, 2001',
#              'id': 'nm0330499',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Patrick Gordon'},
#             {'asCharacter': 'Cleasby 1 episode, 2002',
#              'id': 'nm1140344',
#              'image': 'https://imdb-api.com/images/original/MV5BNjM0MjFmNzAtMGRlMC00ZWM3LTgxMTgtZjAxMDdlNTNkOTAzXkEyXkFqcGdeQXVyNTgwOTM4Mzk@._V1_Ratio1.1364_AL_.jpg',
#              'name': 'Rupert Evans'},
#             {'asCharacter': 'Haley 1 episode, 2002',
#              'id': 'nm2104375',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Rebecca Mordan'},
#             {'asCharacter': 'A.F.R. #1 1 episode, 2002',
#              'id': 'nm1476405',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Kevin Deagle'},
#             {'asCharacter': 'Orlluk 1 episode, 1997',
#              'id': 'nm0476508',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Hussi Kutlucan'},
#             {'asCharacter': 'Mrs. Deebee 1 episode, 1998',
#              'id': 'nm0248231',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Eva Ebner'},
#             {'asCharacter': 'Navigator 1 episode, 1998',
#              'id': 'nm0168453',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Burgandy Code'},
#             {'asCharacter': 'Brother Deal 1 episode, 1999',
#              'id': 'nm0833882',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Tom Petry Strauss'},
#             {'asCharacter': 'Guard 1 1 episode, 1999',
#              'id': 'nm0778659',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Peter Scollin'},
#             {'asCharacter': 'Dream Girl #1 1 episode, 1999',
#              'id': 'nm1561629',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Lee-Anne Lowe'},
#             {'asCharacter': 'Glootus 1 episode, 1999',
#              'id': 'nm2078717',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Karl Lewis Johnston'},
#             {'asCharacter': 'Guard #1 1 episode, 1999',
#              'id': 'nm1587988',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Robin Johnson'},
#             {'asCharacter': 'The Wife 1 episode, 1999',
#              'id': 'nm3399723',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Rosemarie Friedrich'},
#             {'asCharacter': 'Lynx 1 episode, 2000',
#              'id': 'nm1054864',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Katja Richter'},
#             {'asCharacter': 'ATF Agent 1 episode, 2001',
#              'id': 'nm0558536',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'David Matheson'},
#             {'asCharacter': 'Earl 1 episode, 2001',
#              'id': 'nm1125610',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Rejean Cournoyer'},
#             {'asCharacter': 'Boy 1 episode, 2001',
#              'id': 'nm0153011',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'David Charles'},
#             {'asCharacter': 'ATF Agent 1 episode, 2001',
#              'id': 'nm1116865',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Mike Daly'},
#             {'asCharacter': 'French Diplomat 1 episode, 2001',
#              'id': 'nm1152556',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Stan Carew'},
#             {'asCharacter': 'Journalist #2 1 episode, 2001',
#              'id': 'nm1197604',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Karen Beverly'},
#             {'asCharacter': 'Marconi 1 episode, 2001',
#              'id': 'nm1554024',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Giovanni del Vecchio'},
#             {'asCharacter': 'Monk 1 episode, 2002',
#              'id': 'nm0407033',
#              'image': 'https://imdb-api.com/images/original/MV5BMTQ4NjE0MzAxOF5BMl5BanBnXkFtZTcwMjIwMDg4NQ@@._V1_Ratio1.5000_AL_.jpg',
#              'name': 'Togo Igawa'},
#             {'asCharacter': 'Ryan 1 episode, 2002',
#              'id': 'nm1015511',
#              'image': 'https://imdb-api.com/images/original/MV5BMmEwYTFjYmYtNDU3YS00NmEzLWJmYzktYzE1NGI4ZDRlN2VlXkEyXkFqcGdeQXVyMjY1MTYxOA@@._V1_Ratio0.7727_AL_.jpg',
#              'name': 'Finlay Robertson'},
#             {'asCharacter': 'Mort the Mortician 1 episode, 2002',
#              'id': 'nm1141990',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Rory MacGregor'},
#             {'asCharacter': 'Secretary of Defense 1 episode, 2002',
#              'id': 'nm1329655',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Doug Barron'},
#             {'asCharacter': 'Survivalist #2 1 episode, 2002',
#              'id': 'nm1476430',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Shawn Duggan'},
#             {'asCharacter': 'Corporal Harrison Birdie 1 episode, 2002',
#              'id': 'nm0258211',
#              'image': 'https://imdb-api.com/images/original/nopicture.jpg',
#              'name': 'Dennis Envoldsen'},
#             {'asCharacter': 'Grullek 1 episode, 1997',
#              'id': 'nm0115721',
#              'image': 'https://imdb-api.com/images/original/MV5BMzM5MzAwNzU5OF5BMl5BanBnXkFtZTcwMTY4ODkyMQ@@._V1_Ratio1.3182_AL_.jpg',
#              'name': 'Hans-Dieter Brückner'},
#             {'asCharacter': 'Administrator 1 episode, 1998',
#              'id': 'nm0787635',
#              'image': 'https://imdb-api.com/images/original/MV5BM2E1ZWM3OGMtODUyNy00MGVjLThkZGEtNTk2NGVmZGVmZWIyXkEyXkFqcGdeQXVyMjg4MDA4Mw@@._V1_Ratio0.7273_AL_.jpg',
#              'name': 'Errol Shaker'},
#             {'asCharacter': 'Rockhound 1 episode, 1998',
#              'id': 'nm1053933',
#              'image': 'https://imdb-api.com/images/original/MV5BZTY2ZGY2MDktMTcxNS00M2JlLTlmMTAtYzZhYTUxY2Y1NDY1XkEyXkFqcGdeQXVyNjYxMTgzMzQ@._V1_Ratio0.8636_AL_.jpg',
#              'name': 'John Davie'},
#             {'asCharacter': 'Varrtan 1 episode, 1999',
#              'id': 'nm0199139',
#              'image': 'https://imdb-api.com/images/original/MV5BZDlhMWFiZjEtZjNjMC00NWQwLTk2YWQtYmZkNjkzZjBlZjYxXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_Ratio1.5000_AL_.jpg',
#              'name': 'Noah Dalton Danby'},
# ...
#                        {'description': 'production secretary (15 episodes, '
#                                        '1998-1999)',
#                         'id': 'nm4814998',
#                         'name': 'Carmen Perrier'},
#                        {'description': 'assistant accountant (15 episodes, '
#                                        '1998-1999)',
#                         'id': 'nm1404883',
#                         'name': 'Jayn Ritchie'},
#                        {'description': 'production coordinator (15 episodes, '
#                                        '1998-1999)',
#                         'id': 'nm0947526',
#                         'name': 'Sean Yeomans'},
#                        {'description': 'receptionist (14 episodes, 1998-1999)',
#                         'id': 'nm4816337',
#                         'name': 'Alison Mustard'},
#                        {'description': 'assistant to producer / assistant: '
#                                        'Wolfram Tichy / production assistant '
#                                        '(14 episodes, 1999-2000)',
#                         'id': 'nm0069093',
#                         'name': 'Jayne Belliveau'},
#                        {'description': 'production coordinator (13 episodes, '
#                                        '2000)',
#                         'id': 'nm4768224',
#                         'name': 'James Kochanoff'},
#                        {'description': 'systems administrator (12 episodes, '
#                                        '1998-1999)',
#                         'id': 'nm3081433',
#                         'name': 'Carsten Tschach'},
#                        {'description': 'craft service (11 episodes, 2001-2002)',
#                         'id': 'nm4832532',
#                         'name': 'Kimberley Lohnes'},
#                        {'description': 'production assistant (9 episodes, '
#                                        '1999)',
#                         'id': 'nm4815149',
#                         'name': 'Lisa Fancy'},
#                        {'description': 'production assistant (9 episodes, '
#                                        '2000)',
#                         'id': 'nm4825931',
#                         'name': 'Angie Jackson'},
#                        {'description': 'first assistant accountant (9 '
#                                        'episodes, 2000)',
#                         'id': 'nm0747330',
#                         'name': 'Tamara Royce'},
#                        {'description': 'craft service (9 episodes, 2000)',
#                         'id': 'nm0851735',
#                         'name': 'Randy Tavernor'},
#                        {'description': 'key production accountant / production '
#                                        'accountant (8 episodes, 1998-2000)',
#                         'id': 'nm1082582',
#                         'name': 'Rosa Umbach'},
#                        {'description': 'production assistant (8 episodes, '
#                                        '2000)',
#                         'id': 'nm1860965',
#                         'name': 'Preston Hudson'},
#                        {'description': 'production secretary: Germany (7 '
#                                        'episodes, 2000)',
#                         'id': 'nm0466968',
#                         'name': 'Sylvia Koschorreck'},
#                        {'description': 'production coordinator (7 episodes, '
#                                        '2002)',
#                         'id': 'nm1877288',
#                         'name': 'Brian Cosens'},
#                        {'description': 'receptionist (6 episodes, 2002)',
#                         'id': 'nm4850712',
#                         'name': 'Jean MacDonald'},
#                        {'description': 'production secretary / head production '
#                                        'assistant (5 episodes, 1997-1999)',
#                         'id': 'nm3081675',
#                         'name': 'Anke Zwirner'},
#                        {'description': 'production secretary (5 episodes, '
#                                        '1999-2000)',
#                         'id': 'nm2013097',
#                         'name': 'Charlotte Basse'},
#                        {'description': 'accounting clerk (5 episodes, 2000)',
#                         'id': 'nm0545318',
#                         'name': 'Lori March'},
#                        {'description': 'receptionist (5 episodes, 2001-2002)',
#                         'id': 'nm4842158',
#                         'name': 'Zena Leppard'},
#                        {'description': 'assistant accountant (4 episodes, '
#                                        '1998-1999)',
#                         'id': 'nm3081070',
#                         'name': 'Steffi Burck'},
#                        {'description': 'production assistant (4 episodes, '
#                                        '1999)',
#                         'id': 'nm4823112',
#                         'name': 'Robyn McNeil'},
#                        {'description': 'first assistant accountant (4 '
#                                        'episodes, 2000)',
#                         'id': 'nm4834631',
#                         'name': 'Stefanie Burck'},
#                        {'description': 'accounting clerk (4 episodes, 2000)',
#                         'id': 'nm4492754',
#                         'name': 'Claudia Kühn'},
#                        {'description': 'second assistant accountant (4 '
#                                        'episodes, 2000)',
#                         'id': 'nm3363049',
#                         'name': 'Marion Manthey'},
#                        {'description': 'production assistant (4 episodes, '
#                                        '2000)',
#                         'id': 'nm4834641',
#                         'name': 'Nasrin Nadhoda'},
#                        {'description': 'production secretary (2 episodes, '
#                                        '1996-2001)',
#                         'id': 'nm4866172',
#                         'name': 'Koula Bouloukos'},
#                        {'description': 'production secretary (2 episodes, '
#                                        '1996-2001)',
#                         'id': 'nm4866140',
#                         'name': 'Heike Frank'},
#                        {'description': 'production accountant (2 episodes, '
#                                        '1996-1997)',
#                         'id': 'nm0110867',
#                         'name': 'Josée Brodeur'},
#                        {'description': 'studio manager (2 episodes, 1996-1997)',
#                         'id': 'nm0164996',
#                         'name': 'Shaun Clarke'},
#                        {'description': 'assistant accountant (2 episodes, '
#                                        '1996-1997)',
#                         'id': 'nm4866564',
#                         'name': 'Betty Jane Dainard'},
#                        {'description': 'studio coordinator (2 episodes, '
#                                        '1996-1997)',
#                         'id': 'nm0405318',
#                         'name': 'David Hyslop'},
#                        {'description': 'production coordinator (2 episodes, '
#                                        '1996-1997)',
#                         'id': 'nm0245268',
#                         'name': 'Ginny Jones-Duzak'},
#                        {'description': 'assistant to producers (2 episodes, '
#                                        '1996-1997)',
#                         'id': 'nm4867662',
#                         'name': 'Clarence LeBlanc'},
#                        {'description': 'assistant to producer / assistant to '
#                                        'producers (2 episodes, 1996-1997)',
#                         'id': 'nm4867679',
#                         'name': 'Claudia Longerich'},
#                        {'description': 'craft service (2 episodes, 1996-1997)',
#                         'id': 'nm4867654',
#                         'name': 'Julie Millard'},
#                        {'description': 'set production assistant (2 episodes, '
#                                        '1996-1997)',
#                         'id': 'nm0676983',
#                         'name': 'Malve Petersmann'},
#                        {'description': 'set production assistant (2 episodes, '
#                                        '1996-1997)',
#                         'id': 'nm1018746',
#                         'name': 'Pierrette Pretty'},
#                        {'description': 'unit publicist (2 episodes, 1996-1997)',
#                         'id': 'nm0837614',
#                         'name': 'Cornelia Suhr'},
#                        {'description': 'craft service (2 episodes, 1996-1997)',
#                         'id': 'nm4867690',
#                         'name': 'Nancy Warren'},
#                        {'description': 'production assistant (2 episodes, '
#                                        '1998-1999)',
#                         'id': 'nm2419670',
#                         'name': 'Aram Kouyoumdjian'},
#                        {'description': 'script continuity (2 episodes, 2000)',
#                         'id': 'nm0771602',
#                         'name': 'Axel Schill'},
#                        {'description': 'craft service (1 episode, 1996)',
#                         'id': 'nm4867680',
#                         'name': 'Blake Starrat'},
#                        {'description': 'production secretary (1 episode, 1997)',
#                         'id': 'nm2824791',
#                         'name': 'Anja Firmenich'},
#                        {'description': 'office production assistant (1 '
#                                        'episode, 1997)',
#                         'id': 'nm4878987',
#                         'name': 'Max Kirchner'},
#                        {'description': 'production accountant (1 episode, '
#                                        '1997)',
#                         'id': 'nm4878717',
#                         'name': 'Susanne Osterried'},
#                        {'description': 'set production assistant (1 episode, '
#                                        '1997)',
#                         'id': 'nm1211887',
#                         'name': 'Gerhard Weber'},
#                        {'description': 'production assistant (1 episode, 1998)',
#                         'id': 'nm1286295',
#                         'name': 'Paul Vernon'},
#                        {'description': 'dance consultant (1 episode, 1999)',
#                         'id': 'nm4824670',
#                         'name': 'Mary Lou Martin'},
#                        {'description': 'production secretary: Germany (1 '
#                                        'episode, 2000)',
#                         'id': 'nm4318305',
#                         'name': 'Heike Jestram'},
#                        {'description': 'production assistant (1 episode, 2000)',
#                         'id': 'nm4069928',
#                         'name': 'Katinka Seidt'},
#                        {'description': 'production assistant: second unit (1 '
#                                        'episode, 2000)',
#                         'id': 'nm5003350',
#                         'name': 'Zena Snider'},
#                        {'description': 'script continuity (1 episode, 2000)',
#                         'id': 'nm1078945',
#                         'name': 'Claudia Udenta'},
#                        {'description': 'key production assistant (1 episode, '
#                                        '2001)',
#                         'id': 'nm4836365',
#                         'name': 'Don Engelby'},
#                        {'description': 'production secretary (1 episode, 2001)',
#                         'id': 'nm10080373',
#                         'name': 'Elizabeth M. Sawatzky'},
#                        {'description': 'set production assistant (1 episode, '
#                                        '2001)',
#                         'id': 'nm4836710',
#                         'name': 'Cody Young'},
#                        {'description': 'production assistant: Iceland (1 '
#                                        'episode, 2002)',
#                         'id': 'nm4849700',
#                         'name': 'Jon Eldjarn'},
#                        {'description': 'production coordinator: Thailand (1 '
#                                        'episode, 2002)',
#                         'id': 'nm2908842',
#                         'name': 'Tom Pestonji'}],
#              'job': 'Series Additional Crew'}],
#  'title': 'Lexx',
#  'type': 'TVSeries',
#  'writers': {'items': [{'description': '(creator) (61 episodes, 1996-2002)',
#                         'id': 'nm0386601',
#                         'name': 'Jeffrey Hirschfield'},
#                        {'description': '(written by) (61 episodes, 1996-2002)',
#                         'id': 'nm0386601',
#                         'name': 'Jeffrey Hirschfield'},
#                        {'description': '(co-writer) (61 episodes, 1996-2002)',
#                         'id': 'nm0386601',
#                         'name': 'Jeffrey Hirschfield'},
#                        {'description': '(creator) (61 episodes, 1996-2002)',
#                         'id': 'nm0386601',
#                         'name': 'Jeffrey Hirschfield'},
#                        {'description': '(writer) (61 episodes, 1996-2002)',
#                         'id': 'nm0386601',
#                         'name': 'Jeffrey Hirschfield'},
#                        {'description': '(written by) (49 episodes, 1996-2002)',
#                         'id': 'nm0233050',
#                         'name': 'Paul Donovan'},
#                        {'description': '(creator) (49 episodes, 1996-2002)',
#                         'id': 'nm0233050',
#                         'name': 'Paul Donovan'},
#                        {'description': '(creator) (49 episodes, 1996-2002)',
#                         'id': 'nm0233050',
#                         'name': 'Paul Donovan'},
#                        {'description': '(writer) (49 episodes, 1996-2002)',
#                         'id': 'nm0233050',
#                         'name': 'Paul Donovan'},
#                        {'description': '(written by) (45 episodes, 1996-2002)',
#                         'id': 'nm0317596',
#                         'name': 'Lex Gigeroff'},
#                        {'description': '(story department head) (45 episodes, '
#                                        '1996-2002)',
#                         'id': 'nm0317596',
#                         'name': 'Lex Gigeroff'},
#                        {'description': '(creator) (45 episodes, 1996-2002)',
#                         'id': 'nm0317596',
#                         'name': 'Lex Gigeroff'},
#                        {'description': '(creator) (45 episodes, 1996-2002)',
#                         'id': 'nm0317596',
#                         'name': 'Lex Gigeroff'},
#                        {'description': '(writer) (45 episodes, 1996-2002)',
#                         'id': 'nm0317596',
#                         'name': 'Lex Gigeroff'},
#                        {'description': '(2 episodes, 2001-2002)',
#                         'id': 'nm2676664',
#                         'name': 'Andrew Selzer'},
#                        {'description': '(written by) (2 episodes, 2001-2002)',
#                         'id': 'nm2676664',
#                         'name': 'Andrew Selzer'},
#                        {'description': '(writer) (2 episodes, 2001-2002)',
#                         'id': 'nm1529886',
#                         'name': 'Jon Spira'},
#                        {'description': '(written by) (2 episodes, 2001-2002)',
#                         'id': 'nm1529886',
#                         'name': 'Jon Spira'},
#                        {'description': '(written by) (2 episodes, 2001)',
#                         'id': 'nm1079798',
#                         'name': 'Tom de Ville'},
#                        {'description': '(additional writer) (1 episode, 2002)',
#                         'id': 'nm0570128',
#                         'name': 'Frank McGuinness'}],
#              'job': 'Writer'},
#  'year': '1996'}

# %% [markdown]
# Notice that the `asCharacter` field contains a number of different pieces of data as a single string, including the character name.
# This kind of "free-form" text data is notoriously challenging to parse...
#
# ## Exercise 2
#
# In the code cell below, write a python function that takes a string input (the text from `asCharacter` field)
# and returns the number of episodes, if available, or None.
#
# Hints:
# * notice this is a numeric value followed by the word "episodes"
# * recall str.split() and str.isdigit() and other string build-ins.
#
# Add unit tests to cover as many cases from the `actors` data set above as you can.

# %%
def returnNumberOfEpisodes(asCharacter):
  episode = 0
  UnfltrWrds = asCharacter.split(' ')

  for item in UnfltrWrds:
    if (item.isdigit()):
      episode = int(item)

  return episode

# Function Test
numOfEpisodesList = [returnNumberOfEpisodes(item['asCharacter']) for item in actors]
print(numOfEpisodesList)
# Out:
# [61, 61, 57, 55, 46, 23, 16, 8, 13, 10, 7, 8, 3, 5, 6, 7, 7, 5, 5, 6, 5, 4, 5, 5, 5, 5, 5, 1, 4, 4, 4, 2000, 2000, 4, 4, 4, 4, 4, 3, 3, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 3, 2001, 3, 2, 2, 2, 2, 1999, 2, 2001, 2, 2, 2000, 2001, 2001, 2001, 2002, 1999, 2, 2002, 2, 2, 2001, 2, 2, 2, 1997, 2, 2, 2, 2, 2, 2, 2, 1999, 2, 2000, 1, 2001, 1, 1, 1999, 1, 1998, 1999, 1999, 1999, 1999, 1999, 1999, 1999, 2001, 2002, 1997, 1997, 1999, 1999, 1999, 1999, 1999, 1999, 1999, 2000, 2000, 2001, 2002, 2002, 2002, 1999, 1999, 1999, 2000, 2000, 2000, 2000, 2001, 2001, 2002, 2002, 2002, 1996, 1997, 1997, 1997, 1998, 1998, 1999, 1999, 1999, 1999, 1999, 2000, 2000, 2000, 2000, 2001, 2001, 2001, 2001, 2001, 2001, 2002, 2002, 2002, 1997, 1998, 1, 1999, 1999, 1999, 1999, 1999, 2000, 2000, 2000, 2000, 2001, 2001, 2001, 2001, 2001, 2001, 2002, 2002, 2002, 1997, 1998, 1998, 1999, 1999, 1999, 1999, 1999, 1999, 2000, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2002, 2002, 2002, 2002, 2002, 2002, 1997, 1998, 1998, 1999, 1999, 1999, 1999, 1999, 1999, 1999, 2000, 2000, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2002, 2002, 2002, 1997, 1997, 1998, 1999, 1999, 1999, 1999, 1999, 1999, 1999, 2000, 2001, 2001, 2001, 2001, 2001, 2002, 2002, 1, 1998, 1999, 1999, 1999, 2000, 2001, 2001, 2001, 2001, 2002, 2002, 2002, 1999, 1999, 1999, 2000, 2000, 2001, 2001, 2002, 2002, 2002, 1997, 1999, 1999, 2000, 2000, 2001, 2001, 2001, 2001, 2001, 2002, 2002, 2002, 1997, 1999, 1999, 1999, 2000, 2000, 2001, 2001, 2001, 2001, 2001, 2001, 2002, 2002, 2002, 2002, 1997, 1999, 2000, 2001, 2001, 2001, 2001, 2001, 2002, 2002, 1999, 2000, 2001, 2001, 2001, 2001, 2002, 2002, 2000, 2001, 2001, 2001, 2001, 2001, 2002, 2002, 1997, 2000, 2000, 2001, 2001, 2001, 2001, 2001, 2002, 2002, 1997, 2000, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 1997, 2001, 2001, 2001, 2001, 1996, 2001, 2001, 2001, 1996, 1996, 1996, 1996, 1996, 1, 1996, 1996, 1997, 1997, 2002, 2, 2001, 1996, 2000, 2000, 2001, 2001]

# %% [markdown]
# ## Exercise 3
#
# In the code cell below, write a python function that takes a string input (the text from `asCharacter` field)
# and returns just the character name.  This one may be even a little harder!
#
# Hints:
# * notice the character name is usually followed by a forward slash, `/`
# * don't worry if your algorithm does not perfectly parse every character's name --
# it may not really be possible to correclty handle all cases because the field format does not follow consistent rules
#
# Add unit tests to cover as many cases from the `actors` data set above as you can.

# %%
def returnCharacterName(asCharacter):
  name = ''
  unFltrdWrd = asCharacter.split(' ')

  for item in unFltrdWrd:
    if(item == '/'):
      break
    else:
      name = name + ' ' + item
  return name

# Function Test
characterNames = [returnCharacterName(item['asCharacter']) for item in actors]
print(characterNames)
# Out:
# [' Stanley H. Tweedle', ' Kai', ' 790', ' Xev Bellringer', ' The Lexx 46 episodes, 1996-2002', ' Prince', ' Bunny Priest', ' Bound Man', ' Reginald J. Priest', ' Lyekka', ' Divine Predecessor', ' His Divine Shadow', ' Mothbreeder', ' Vlad', ' Megashadow Adjutant', ' Zev Bellringer 7 episodes, 1996-2000', ' Giggerota', ' The Time Prophet', ' Mantrid 5 episodes, 1998-2000', ' Fifi', ' Holo Cleric', ' Dougall 4 episodes, 2001-2002', ' Jood', ' Transport Major', ' Child', ' Holo Lawyr', ' Video Customs Officer', ' Mothbreeder', ' Petrif', ' Joshua', ' Holo Judge', ' Duke 5 episodes, 2000', ' May 5 episodes, 2000', ' Anchorman', ' Tina 4 episodes, 2001-2002', ' Lead Balloonist', ' Handler 2', ' Archaeologist', ' Matron', ' Brock', ' Blue Team Member', ' Megashadow Admiral 4 episodes, 1996-1997', ' Tem 4 episodes, 1996-1997', ' Wig Girl 4 episodes, 1996-1997', ' Correction Center Guard 4 episodes, 1996-1997', ' Honar 4 episodes, 1996-1997', ' Monk 4 episodes, 1996-1997', ' Scientist 4 episodes, 1996-1997', ' Cluster Major 4 episodes, 1996-1997', ' Rebel 4 episodes, 1996-1997', ' E.J. Moss, Commander of Eagle 5', ' Digby 3 episodes, 2001', ' Big Angry Ed', ' First Lady Priest', ' Moth Breeder', ' Moth Breeder 2 episodes, 2001-2002', ' Louie', ' Norb', ' Boork', ' Davinia Silver', ' Lomea', ' 791', ' Chief Handler 2 episodes, 2000', ' Joseph Van Helsing 2 episodes, 2001', ' Dad', ' Muffy', ' Gordon 2 episodes, 2002', ' Dream Girl #2', ' ATF Agent #1', ' Skankita 2 episodes, 2002', ' Road Worker', ' Root', ' Mandragora Morgana', ' Flintokk, Head Pimp Sister', ' Doily', ' Argon Protopi', ' Reteep', ' Commentator', ' Rexal', ' Eco Tourist #2', ' Computer', ' Bellhop', ' Middle aged woman', ' 790 Robot', ' Pa Gollean', ' Original Xev', ' Priest', ' Desh', ' Peasant 1 episode, 2001', ' Druid Girl', ' Black Pawn #3', ' C.G. 1 episode, 1999', ' Thief', ' Dr. Kazan 1 episode, 1998', ' The Dark Lady 1 episode, 1999', ' Captain Jebbed 1 episode, 1999', ' Grand Prosecutor Jihana 1 episode, 1999', ' Brizon 1 episode, 1999', ' Enox 1 episode, 1999', ' Brother Randor 1 episode, 1999', ' Master of Ceremonies 1 episode, 1999', ' Card Carrying Druid 1 episode, 2001', ' Deputy Festus Trout 1 episode, 2002', ' Poet Man 1 episode, 1997', ' Smoor 1 episode, 1997', ' Gubby Mok 1 episode, 1999', ' Heedia 1 episode, 1999', ' Tad 1 episode, 1999', ' Sissy Gollean 1 episode, 1999', ' Aulk 1 episode, 1999', ' Brother Treygor 1 episode, 1999', ' Slinka 1 episode, 1999', ' Rivet 1 episode, 2000', ' Lily 1 episode, 2000', ' Cellphone Druid 1 episode, 2001', ' Dulcibella Sternflanks 1 episode, 2002', ' Amber 1 episode, 2002', ' Bereaved Mom 1 episode, 2002', ' Nurse', ' Junior Gollean 1 episode, 1999', ' Groo 1 episode, 1999', ' Tish 1 episode, 2000', ' Wench 1 episode, 2000', ' Tulip 1 episode, 2000', ' Minx 1 episode, 2000', ' Colin 1 episode, 2001', ' Merle 1 episode, 2001', ' Didi Figgleshrick 1 episode, 2002', ' Wyatt 1 episode, 2002', ' FBI Lieutenant 1 episode, 2002', ' Thodin 1 episode, 1996', ' Yottskry 1 episode, 1997', ' Snik 1 episode, 1997', ' Holo Woman 1 episode, 1997', ' L.L. Boosh 1 episode, 1998', ' Dr. Funz 1 episode, 1998', ' Nool 1 episode, 1999', ' Rissha 1 episode, 1999', ' Kanana 1 episode, 1999', ' Skye 1 episode, 1999', ' Kyoo 1 episode, 1999', ' Hammer 1 episode, 2000', ' Cab 1 episode, 2000', ' Dr. Bunz 1 episode, 2000', ' Daisy 1 episode, 2000', ' Oliver 1 episode, 2001', ' Puck 1 episode, 2001', ' Executive 1 episode, 2001', ' Native American Leader 1 episode, 2001', ' Tourist 1 episode, 2001', ' Older Woman 1 episode, 2001', ' Josh 1 episode, 2002', ' Queen of Sheba 1 episode, 2002', ' Burl 1 episode, 2002', " Zev's Mother 1 episode, 1997", ' Dr. Veezra 1 episode, 1998', ' Fruitcake 1 episode, 1999-2000', ' Calico 1 episode, 1999', ' Lissha 1 episode, 1999', ' Older Brother 1 episode, 1999', ' Gibble 1 episode, 1999', ' New Born 1 episode, 1999', ' Daffodil 1 episode, 2000', ' Socket 1 episode, 2000', ' Zin 1 episode, 2000', ' Fox 1 e ...

# %% [markdown]
# ## Exercise 4
#
# Using the functions you developed above, define 2 list comprehensions that:
# * create list of 2 tuples with (actor name, character description) for actors in Lexx  (from `asCharacter` field)
# * create a list of dictionaries, with keys:  'actor' and 'character' for the same data
#
# Hint: this is a very simple problem - the goal is to learn how to build these lists using a comprehension.
#
# Pretty print (pprint) your lists to visually verify the results.

# %%
actorDetails = [(item['name'], item['asCharacter']) for item in actors]
dictList = [{ 'actor': item['name'], 'character': item["asCharacter"] } for item in actors]

#Test
pprint(actorDetails)
pprint(dictList)
# Out:
# [('Brian Downey', 'Stanley H. Tweedle / ... 61 episodes, 1996-2002'),
#  ('Michael McManus', 'Kai / ... 61 episodes, 1996-2002'),
#  ('Jeffrey Hirschfield', '790 / ... 57 episodes, 1996-2002'),
#  ('Xenia Seeberg', 'Xev Bellringer / ... 55 episodes, 1998-2002'),
#  ('Tom Gallant', 'The Lexx 46 episodes, 1996-2002'),
#  ('Nigel Bennett', 'Prince / ... 23 episodes, 2000-2002'),
#  ('Patricia Zentilli', 'Bunny Priest / ... 16 episodes, 1999-2002'),
#  ('Lex Gigeroff', 'Bound Man / ... 8 episodes, 1996-2002'),
#  ('Rolf Kanies', 'Reginald J. Priest / ... 13 episodes, 2000-2002'),
#  ('Louise Wischermann', 'Lyekka / ... 10 episodes, 1998-2002'),
#  ('John Dunsworth', 'Divine Predecessor / ... 7 episodes, 1996-2002'),
#  ('Walter Borden', 'His Divine Shadow / ... 8 episodes, 1996-2002'),
#  ('David Albiston', 'Mothbreeder / ... 3 episodes, 1998-2002'),
#  ('Minna Aaltonen', 'Vlad / ... 5 episodes, 2001-2002'),
#  ('Clive Sweeney', 'Megashadow Adjutant / ... 6 episodes, 1996-2000'),
#  ('Eva Habermann', 'Zev Bellringer 7 episodes, 1996-2000'),
#  ('Ellen Dubin', 'Giggerota / ... 7 episodes, 1996-2002'),
#  ('Anna Cameron', 'The Time Prophet / ... 5 episodes, 1996-2002'),
#  ('Dieter Laser', 'Mantrid 5 episodes, 1998-2000'),
#  ('Jeff Pustil', 'Fifi / ... 6 episodes, 1999-2001'),
#  ('David McClelland', 'Holo Cleric / ... 5 episodes, 1996-2001'),
#  ('Kevin Curran', 'Dougall 4 episodes, 2001-2002'),
#  ('Jamie Bradley', 'Jood / ... 5 episodes, 1996-2001'),
#  ('Jeremy Akerman', 'Transport Major / ... 5 episodes, 1996-1999'),
#  ('Nicolás Artajo', 'Child / ... 5 episodes, 1996-1999'),
#  ('John Dartt', 'Holo Lawyr / ... 5 episodes, 1996-2002'),
#  ('Chas Lawther', 'Video Customs Officer / ... 5 episodes, 1996-2001'),
#  ('Todd Godin', 'Mothbreeder / ... 1 episode, 2000-2002'),
#  ('Robert Sigl', 'Petrif / ... 4 episodes, 1996-2000'),
#  ('David Renton', 'Joshua / ... 4 episodes, 1996-2000'),
#  ('Lionel Doucette', 'Holo Judge / ... 4 episodes, 1996-1999'),
#  ('Ralph Brown', 'Duke 5 episodes, 2000'),
#  ('Anna Kathrin Bleuler', 'May 5 episodes, 2000'),
#  ('Tony Anholt', 'Anchorman / ... 4 episodes, 2001-2002'),
#  ('Tara Doyle', 'Tina 4 episodes, 2001-2002'),
#  ('Gary Levert', 'Lead Balloonist / ... 4 episodes, 2000-2002'),
#  ('Jon K. Loverin', 'Handler 2 / ... 4 episodes, 1999-2001'),
#  ('Glenn Wadman', 'Archaeologist / ... 4 episodes, 1996-2002'),
#  ('Jennifer Overton', 'Matron / ... 3 episodes, 1997-2000'),
#  ('Geoff Herod', 'Brock / ... 3 episodes, 2000-2001'),
#  ('Glen Grant', 'Blue Team Member / ... 1 episode, 2000-2002'),
#  ('Richard Donat', 'Megashadow Admiral 4 episodes, 1996-1997'),
#  ('Gil Brenton', 'Tem 4 episodes, 1996-1997'),
#  ('Barbara Kowa', 'Wig Girl 4 episodes, 1996-1997'),
#  ('Bill Carr', 'Correction Center Guard 4 episodes, 1996-1997'),
#  ('Sanjay Talwar', 'Honar 4 episodes, 1996-1997'),
#  ('Clemens von Tubeuf', 'Monk 4 episodes, 1996-1997'),
#  ('Gary Vermeir', 'Scientist 4 episodes, 1996-1997'),
#  ('Jocelyn Cunningham', 'Cluster Major 4 episodes, 1996-1997'),
#  ('Andrei Mahankov', 'Rebel 4 episodes, 1996-1997'),
#  ('Stephen McHattie',
#   'E.J. Moss, Commander of Eagle 5 / ... 3 episodes, 1998-2002'),
#  ('Ryan Cooley', 'Digby 3 episodes, 2001'),
#  ('Mark A. Owen', 'Big Angry Ed / ... 3 episodes, 1999-2001'),
#  ('Janet Wright', 'First Lady Priest / ... 2 episodes, 1999-2001'),
#  ('Geoff McBride', 'Moth Breeder / ... 2 episodes, 2001-2002'),
#  ('Jenson Vaughan', 'Moth Breeder 2 episodes, 2001-2002'),
#  ('Louis Del Grande', 'Louie / ... 2 episodes, 1999-2002'),
#  ('Brandon McCarvell', 'Norb / ... 2 episodes, 1999'),
#  ('Holger Kunkel', 'Boork / ... 2 episodes, 1997-1998'),
#  ('Andrea Green', 'Davinia Silver / ... 2 episodes, 2001'),
#  ('Lauren Abrahams', 'Lomea / ... 2 episodes, 1999-2001'),
#  ('Brian Carter', '791 / ... 2 episodes, 1999-2002'),
#  ('Linda Busby', 'Chief Handler 2 episodes, 2000'),
#  ('Peter Guinness', 'Joseph Van Helsing 2 episodes, 2001'),
#  ('Stephen Coats', 'Dad / ... 2 episodes, 2001'),
#  ('Angie Hill', 'Muffy / ... 2 episodes, 2001'),
#  ('Dan Fredenburgh', 'Gordon 2 episodes, 2002'),
#  ('Laura Mae Nason', 'Dream Girl #2 / ... 2 episodes, 1999'),
#  ('Chris Duffy', 'ATF Agent #1 / ... 2 episodes, 1998-2001'),
#  ('Marem Hassler', 'Skankita 2 episodes, 2002'),
#  ('Michael Pellerin', 'Road Worker / ... 2 episodes, 1999-2002'),
#  ('Landy Cannon', 'Root / ... 2 episodes, 2000-2002'),
#  ('Rachel Mooney', 'Mandragora Morgana / ... 2 episodes, 2001'),
#  ('Stephen J.M. Sisk',
#   'Flintokk, Head Pimp Sister / ... 2 episodes, 1999-2000'),
#  ('Andre Haines', 'Doily / ... 2 episodes, 1999-2000'),
#  ('Alan MacGillivray', 'Argon Protopi / ... 2 episodes, 1996-1999'),
#  ('Shaun Clarke', 'Reteep / ... 2 episodes, 1997'),
#  ('Graham Pountney', 'Commentator / ... 2 episodes, 2001-2002'),
#  ('Sam White', 'Rexal / ... 2 episodes, 1999-2001'),
#  ('Andy Smith', 'Eco Tourist #2 / ... 2 episodes, 1999-2001'),
#  ('Angela Vermeir', 'Computer / ... 2 episodes, 1999-2001'),
#  ('Jack Carr', 'Bellhop / ... 2 episodes, 1996-2002'),
#  ('Sherry White', 'Middle aged woman / ... 2 episodes, 1999-2001'),
#  ('Mike Petersen', '790 Robot / ... 2 episodes, 1996-1997'),
#  ('Maury Chaykin', 'Pa Gollean / ... 1 episode, 1999'),
#  ('Lisa Hynes', 'Original Xev / ... 2 episodes, 1996-2000'),
#  ('Malcolm Younger', 'Priest / ... 1 episode, 2000'),
#  ('Amy Kerr', 'Desh / ... 1 episode, 1999-2002'),
#  ('Jeri-Matti Helppi', 'Peasant 1 episode, 2001'),
#  ('Cindy Sampson', 'Druid Girl / ... 1 episode, 1999-2001'),
#  ('Joshua Young', 'Black Pawn #3 / ... 1 episode, 2001-2002'),
#  ('Tom Tasse', 'C.G. 1 episode, 1999'),
#  ('Gordon Patrick White', 'Thief / ... 1 episode, 1999-2001'),
#  ('Simon Licht', 'Dr. Kazan 1 episode, 1998'),
#  ('Lenore Zann', 'The Dark Lady 1 episode, 1999'),
#  ('Page Fletcher', 'Captain Jebbed 1 episode, 1999'),
#  ('Nina Franoszek', 'Grand Prosecutor Jihana 1 episode, 1999'),
#  ('Earl Pastko', 'Brizon 1 episode, 1999'),
#  ('Andrew Bigelow', 'Enox 1 episode, 1999'),
#  ('Matthew Burton', 'Brother Randor 1 episode, 1999'),
#  ('Jeremy Webb', 'Master of Ceremonies 1 episode, 1999'),
#  ('Richard Braine', 'Card Carrying Druid 1 episode, 2001'),
#  ('Nick Cawdron', 'Deputy Festus Trout 1 episode, 2002'),
#  ('Tim Curry', 'Poet Man 1 episode, 1997'),
#  ('Andy Jones', 'Smoor 1 episode, 1997'),
#  ('Wayne Robson', 'Gubby Mok 1 episode, 1999'),
#  ('Mary Walsh', 'Heedia 1 episode, 1999'),
#  ('Andrew Bush', 'Tad 1 episode, 1999'),
#  ('Susan Quinn', 'Sissy Gollean 1 episode, 1999'),
#  ('Diego Chambers', 'Aulk 1 episode, 1999'),
#  ('Matthias Klimsa', 'Brother Treygor 1 episode, 1999'),
#  ('Barbara Schmied', 'Slinka 1 episode, 1999'),
#  ('Polly Jo Pleasence', 'Rivet 1 episode, 2000'),
#  ('Julia Haacke', 'Lily 1 episode, 2000'),
#  ('David Christoffel', 'Cellphone Druid 1 episode, 2001'),
#  ('Britt Ekland', 'Dulcibella Sternflanks 1 episode, 2002'),
#  ('Polly Green', 'Amber 1 episode, 2002'),
#  ('Kathryn Fraser', 'Bereaved Mom 1 episode, 2002'),
#  ('Sandra Keller', 'Nurse / ... 1 episode, 1999'),
#  ('Dave Carmichael', 'Junior Gollean 1 episode, 1999'),
#  ('Sharon Timmins', 'Groo 1 episode, 1999'),
#  ('Sandra S. Leonhard', 'Tish 1 episode, 2000'),
#  ('Terry Neason', 'Wench 1 episode, 2000'),
#  ('Hephzibah Tintner', 'Tulip 1 episode, 2000'),
#  ('Nicole Ciroth', 'Minx 1 episode, 2000'),
#  ('Nick Ewans', 'Colin 1 episode, 2001'),
#  ('Michael Best', 'Merle 1 episode, 2001'),
#  ('Celia Henebury', 'Didi Figgleshrick 1 episode, 2002'),
#  ('Mason Phillips', 'Wyatt 1 episode, 2002'),
#  ('Donald Chisholm', 'FBI Lieutenant 1 episode, 2002'),
#  ('Barry Bostwick', 'Thodin 1 episode, 1996'),
#  ('Malcolm McDowell', 'Yottskry 1 episode, 1997'),
#  ('Gerry Wolff', 'Snik 1 episode, 1997'),
#  ('Kate Rose', 'Holo Woman 1 episode, 1997'),
#  ('Roman Podhora', 'L.L. Boosh 1 episode, 1998'),
#  ('Oliver Stern', 'Dr. Funz 1 episode, 1998'),
#  ('Benjamin Sadler', 'Nool 1 episode, 1999'),
#  ('Ellen-Ray Hennessy', 'Rissha 1 episode, 1999'),
#  ('Nikki Barnett', 'Kanana 1 episode, 1999'),
#  ('Kerry McPherson', 'Skye 1 episode, 1999'),
#  ('Paul McQuillan', 'Kyoo 1 episode, 1999'),
#  ('Diane Langton', 'Hammer 1 episode, 2000'),
#  ('Urs Remond', 'Cab 1 episode, 2000'),
#  ('Udo Jolly', 'Dr. Bunz 1 episode, 2000'),
#  ('Sabrina Rattey', 'Daisy 1 episode, 2000'),
#  ('Peter Blake', 'Oliver 1 episode, 2001'),
#  ('Tim Frances', 'Puck 1 episode, 2001'),
#  ('Howard Attfield', 'Executive 1 episode, 2001'),
#  ('Agumeuay Nakanakis', 'Native American Leader 1 episode, 2001'),
#  ('Danielle Dawe', 'Tourist 1 episode, 2001'),
#  ('Lois Brown', 'Older Woman 1 episode, 2001'),
#  ('Johnny Lomas', 'Josh 1 episode, 2002'),
#  ('Andrulla Blanchette', 'Queen of Sheba 1 episode, 2002'),
#  ('John Diamond', 'Burl 1 episode, 2002'),
#  ('Rachel Grover', "Zev's Mother 1 episode, 1997"),
#  ('Barbara Geiger', 'Dr. Veezra 1 episode, 1998'),
#  ('David Lewis', 'Fruitcake 1 episode, 1999-2000'),
#  ('Stacy Smith', 'Calico 1 episode, 1999'),
#  ('Susanna Metzner', 'Lissha 1 episode, 1999'),
#  ('Martin Höner', 'Older Brother 1 episode, 1999'),
#  ('Bruce Fillmore', 'Gibble 1 episode, 1999'),
#  ('Joe Wynn', 'New Born 1 episode, 1999'),
#  ('Ina Paule Klink', 'Daffodil 1 episode, 2000'),
#  ('Jelena Budimir', 'Socket 1 episode, 2000'),
#  ('Hans Brückner', 'Zin 1 episode, 2000'),
#  ('Katrin Schrake', 'Fox 1 episode, 2000'),
#  ('Craig Charles', 'The Warden 1 episode, 2001'),
#  ('Jay Benedict', 'Vet 1 episode, 2001'),
#  ('Brian Buckley', 'George 1 episode, 2001'),
#  ('Alexis Conran', 'Mustafa Al Hambra 1 episode, 2001'),
#  ('Bob Dearden', 'Dale 1 episode, 2001'),
#  ('Patrick Gordon', 'Oberon 1 episode, 2001'),
#  ('Rupert Evans', 'Cleasby 1 episode, 2002'),
#  ('Rebecca Mordan', 'Haley 1 episode, 2002'),
#  ('Kevin Deagle', 'A.F.R. #1 1 episode, 2002'),
#  ('Hussi Kutlucan', 'Orlluk 1 episode, 1997'),
#  ('Eva Ebner', 'Mrs. Deebee 1 episode, 1998'),
#  ('Burgandy Code', 'Navigator 1 episode, 1998'),
#  ('Tom Petry Strauss', 'Brother Deal 1 episode, 1999'),
#  ('Peter Scollin', 'Guard 1 1 episode, 1999'),
#  ('Lee-Anne Lowe', 'Dream Girl #1 1 episode, 1999'),
#  ('Karl Lewis Johnston', 'Glootus 1 episode, 1999'),
#  ('Robin Johnson', 'Guard #1 1 episode, 1999'),
#  ('Rosemarie Friedrich', 'The Wife 1 episode, 1999'),
#  ('Katja Richter', 'Lynx 1 episode, 2000'),
#  ('David Matheson', 'ATF Agent 1 episode, 2001'),
#  ('Rejean Cournoyer', 'Earl 1 episode, 2001'),
#  ('David Charles', 'Boy 1 episode, 2001'),
#  ('Mike Daly', 'ATF Agent 1 episode, 2001'),
#  ('Stan Carew', 'French Diplomat 1 episode, 2001'),
#  ('Karen Beverly', 'Journalist #2 1 episode, 2001'),
#  ('Giovanni del Vecchio', 'Marconi 1 episode, 2001'),
#  ('Togo Igawa', 'Monk 1 episode, 2002'),
#  ('Finlay Robertson', 'Ryan 1 episode, 2002'),
#  ('Rory MacGregor', 'Mort the Mortician 1 episode, 2002'),
#  ('Doug Barron', 'Secretary of Defense 1 episode, 2002'),
#  ('Shawn Duggan', 'Survivalist #2 1 episode, 2002'),
#  ('Dennis Envoldsen', 'Corporal Harrison Birdie 1 episode, 2002'),
#  ('Hans-Dieter Brückner', 'Grullek 1 episode, 1997'),
#  ('Errol Shaker', 'Administrator 1 episode, 1998'),
#  ('John Davie', 'Rockhound 1 episode, 1998'),
#  ('Noah Dalton Danby', 'Varrtan 1 episode, 1999'),
#  ('C.J. Lusby', 'Nympho 1 1 episode, 1999'),
#  ('Harvey Friedman', 'Guard 3 1 episode, 1999'),
#  ('Christian Murray', '792 1 episode, 1999'),
#  ('Lorraine Segato', 'Time Prophet 1 episode, 1999'),
#  ('Philippe Roche', 'Brother Stack / ... 1 episode, 1999'),
#  ('Christian Murray', 'Gold Lamé Man 1 episode, 1999'),
#  ('Jimmy Somerville', 'Satin 1 episode, 2000'),
#  ('Rose Zone', 'Bruise 1 episode, 2000'),
#  ('Clive Merrison', 'Professor Shnoog 1 episode, 2001'),
#  ('Alun Lewis',
#   'Uther de Glastonbury, formerly known as Nigel Bumsen 1 episode, 2001'),
#  ('John Gleeson', 'Doctor 1 episode, 2001'),
#  ('David Francis', 'Newfie 1 episode, 2001'),
#  ('Lee J. Campbell', 'Journalist #1 1 episode, 2001'),
#  ('Melanie Harris', 'Marjorie 1 episode, 2001'),
#  ('James Crossley', 'Chad 1 episode, 2001'),
#  ('Philip Dinn', 'Local 1 episode, 2001'),
#  ('Seán Cullen', 'Remo 1 episode, 2002'),
#  ('Richard Hanson', 'Devlin 1 episode, 2002'),
#  ('Geoffrey McLean', 'Middle Aged Son 1 episode, 2002'),
#  ('Rainer Matsutani', 'Brunnen-G General 1 episode, 1997'),
#  ('Arno Wyzniewski', 'Kuk 1 episode, 1997'),
#  ('Ian T. Dickinson', 'Berg 1 episode, 1998'),
#  ('Milton Welsh', 'Rat II 1 episode, 1999'),
#  ('Thorsten Feller', 'Liggum 1 episode, 1999'),
#  ('Amy Lonergan', 'Dream Girl #3 1 episode, 1999'),
#  ('Alison McMullin', 'Nympho 2 1 episode, 1999'),
#  ('Paul Day', 'Consort 1 episode, 1999'),
#  ('Dick Sircom', 'Judge 1 episode, 1999'),
#  ('Adrienne Horton', 'Guard #3 1 episode, 1999'),
#  ('Peter Baylis', 'First Balloonist 1 episode, 2000'),
#  ('Lionel Jeffries', 'Father Borscht 1 episode, 2001'),
#  ('Mick Walter', 'Titania 1 episode, 2001'),
#  ('Jim Fowler', 'Rooster 1 episode, 2001'),
#  ('Ken Shipley', 'Produce Manager 1 episode, 2001'),
#  ('Tom Haney', 'Studio Guard 1 episode, 2001'),
#  ('Sam Douglas', 'General Klebstock 1 episode, 2002'),
#  ('Mike Durling', 'Joey 1 episode, 2002'),
#  ('Michael Habeck', 'Feppo 1 episode, 1997-1999'),
#  ('Tatjana Alexander', 'Nurse 1 episode, 1998'),
#  ('Gabi Fleming', 'Dead Female Body 1 episode, 1999'),
#  ('Lori Heath', 'Hologram Guard 1 episode, 1999'),
#  ('Adrian Mattiske', 'Young Copying Brother 1 episode, 1999'),
#  ('Janaya Stephens', 'Peach 1 episode, 2000'),
#  ('Keith-Lee Castle', 'Renfield 1 episode, 2001'),
#  ('Jeremy Peters', 'Surgeon 1 episode, 2001'),
#  ('Jason Hemsworth', 'Secret Service Agent 1 episode, 2001'),
#  ('Andrea Dymond', 'Goth Prisoner 1 episode, 2001'),
#  ('Michael J. Reynolds', 'Colonel Donald K. Gore 1 episode, 2002'),
#  ('William Parsons', 'Older Husband 1 episode, 2002'),
#  ('Nancy Marshall', 'Geekette 1 episode, 2002'),
#  ('Rick Collins', 'Fat Man 1 episode, 1999'),
#  ('Greg Cormier', 'Bound Man 1 episode, 1999'),
#  ('Thomas Arnicke', 'Bodyguard 1 episode, 1999'),
#  ('Wanja Mues', 'Pearl 1 episode, 2000'),
#  ('Robyn Palmer', 'Pear 1 episode, 2000'),
#  ('Martha Irving', 'Doris 1 episode, 2001'),
#  ('Travis Ferris', 'Guard #2 1 episode, 2001'),
#  ('Kevin LeBlanc', 'FBI Agent #1 1 episode, 2002'),
#  ('Mary Alvena Poole', 'Older Wife 1 episode, 2002'),
#  ('Paul Jessen', 'ATF Officer 1 episode, 2002'),
#  ('Jim Petrie', 'Gorrett 1 episode, 1997'),
#  ('Terry Nicholas', 'First Babe 1 episode, 1999'),
#  ('Al Mueller', 'Bodyguard 1 episode, 1999'),
#  ('Roberta Angelica', 'Plum 1 episode, 2000'),
#  ('Roger Tebb', 'Silk 1 episode, 2000'),
#  ('Robert Maillet', 'Leroy 1 episode, 2001'),
#  ('Frank Kelly', 'Father Pickle 1 episode, 2001'),
#  ('Richard Hards', 'Nelson 1 episode, 2001'),
#  ('Arthur Spray', 'Gypsy Servant 1 episode, 2001'),
#  ('Bill Jessome', 'Chief Justice 1 episode, 2001'),
#  ('Kelsa Kinsly', 'Slave Girl 88 1 episode, 2002'),
#  ('Jesse Lund', 'Rod 1 episode, 2002'),
#  ('Stephanie Redding', 'Twin Daughter 1 episode, 2002'),
#  ('Sherry Devanney', 'Kyyra 1 episode, 1997'),
#  ('Lisa Wong', 'Second Babe 1 episode, 1999'),
#  ('Dave Maddeaux', 'Male Customer 1 episode, 1999'),
#  ('Mirko Szabo', 'Bodyguard 1 episode, 1999'),
#  ('Mika Ward', 'Cherry 1 episode, 2000'),
#  ('Georg Tryphon', 'Lace 1 episode, 2000'),
#  ('John Standing', 'Count Dracul 1 episode, 2001'),
#  ('Chris Owens', 'Biff 1 episode, 2001'),
#  ('Hattie Hayridge', 'Sub-Warden Heidi 1 episode, 2001'),
#  ('Bette MacDonald', 'Marge 1 episode, 2001'),
#  ('Madeleine Lefebvre', 'Eco Tourist #1 1 episode, 2001'),
#  ('Gareth Miller', 'Lieutenant 1 episode, 2001'),
#  ('John Lebar', 'The Mummy - Draco 1 episode, 2002'),
#  ('Ryan McCluskey', 'Tad 1 episode, 2002'),
#  ('Nicole Redding', 'Dead Twin Daughter 1 episode, 2002'),
#  ('Cleveland Sauer', 'Survivalist 1 episode, 2002'),
#  ('Joel Sapp', 'Bleeding Cleric / ... 1 episode, 1997'),
#  ('Sebastian Kokot', 'Bodyguard 1 episode, 1999'),
#  ('Renate Spona', 'Guard #1 1 episode, 2000'),
#  ('Ed Macdonald', 'Leo 1 episode, 2001'),
#  ('Maggie Holland', 'Elderly Lady 1 episode, 2001'),
#  ('Nunzio Lombardo', 'Valentino 1 episode, 2001'),
#  ('Stephen Morgan', 'Chip 1 episode, 2001'),
#  ('Dan Steeves', 'Store Guard 1 episode, 2001'),
#  ('Marguerite McNeil', 'Stress Counselor 1 episode, 2002'),
#  ('Dominic Pallotta', 'Frankie 1 episode, 2002'),
#  ('Oliver Stolz', 'Bodyguard 1 episode, 1999'),
#  ('Sabine Winterfeldt', 'Guard #2 1 episode, 2000'),
#  ("Ross O'Hennessy", 'Cedric 1 episode, 2001'),
#  ('Alec Linstead', 'Cardinal Meinpo Duftet 1 episode, 2001'),
#  ('Douglas Mayr', 'Bartender 1 episode, 2001'),
#  ('James Reeve', 'Sheriff 1 episode, 2001'),
#  ('Laura Patch', 'Piccalina 1 episode, 2002'),
#  ('Jeremiah Sparks', 'Cabbie 1 episode, 2002'),
#  ('Thordis König', 'Guard #3 1 episode, 2000'),
#  ('David Verrey', 'Businessman 1 episode, 2001'),
#  ('Justin Pierre', 'Bob 1 episode, 2001'),
#  ('Rhonda McLean', 'Mom 1 episode, 2001'),
#  ('Julia Moore', 'Truro 1 episode, 2001'),
#  ('Lydia Klenck', 'Shower Nude #1 1 episode, 2001'),
#  ('Tricia Taylor', 'Love Slave Wrestler 1 episode, 2002'),
#  ('Jason Sweeney', 'Rex 1 episode, 2002'),
#  ('Lenuta Sim', 'Dancing Twin #2 1 episode, 1997'),
#  ('Gina Fischer', 'Guard #4 1 episode, 2000'),
#  ('Craig Wood', 'Chief Guard 1 episode, 2000'),
#  ('Silvio Simac', 'Hank 1 episode, 2001'),
#  ('Heather Rankin', 'Phoebe 1 episode, 2001'),
#  ('John Pearson', 'Cobra 1 episode, 2001'),
#  ('Beth Mahaney', 'Shower Nude #2 1 episode, 2001'),
#  ('Bruce Murphy', 'Junior 1 episode, 2001'),
#  ('Heidi von Palleske', 'Slave Girl 24 1 episode, 2002'),
#  ('Matt Zimmerman', 'Supervisor 1 episode, 2002'),
#  ('Mariana Sim', 'Dancing Twin #1 1 episode, 1997'),
#  ('Jana Piehl', 'Guard #5 1 episode, 2000'),
#  ('Jamie Sparks', 'Passenger 1 episode, 2001'),
#  ('Peter James', 'Guard #1 1 episode, 2001'),
#  ('Raymond Solomon', 'Jacques 1 episode, 2001'),
#  ('Maisie Rillie', 'Sharon 1 episode, 2001'),
#  ('Andy Gatjen', 'Ridolan 1 episode, 2001'),
#  ('Shooglenifty', 'Themselves 1 episode, 2001'),
#  ('Rupert Solomon', 'Pierce 1 episode, 2001'),
#  ('Marcos Troy', 'Malik 1 episode, 2001'),
#  ('Malcolm Cosbie', 'Self - Band 1 episode, 2001'),
#  ('David Woods', 'Yoyal 1 episode, 1997'),
#  ('Georgia Zaris', "Farley's Assistant 1 episode, 2001"),
#  ('Jim Swansburg', 'Cmdr. Bricklin 1 episode, 2001'),
#  ('Garry Finlayson', 'Self - Band 1 episode, 2001'),
#  ('Craig Gaskin', 'Self - Band 1 episode, 2001'),
#  ('Josh MacDonald', 'Sergeant 1 episode, 1996'),
#  ('Angus Grant', 'Self - Band 1 episode, 2001'),
#  ('Ian MacLeod', 'Self - Band 1 episode, 2001'),
#  ('Conrad Molleson', 'Self - Band 1 episode, 2001'),
#  ('Horst Ulan', 'Cluster General 1 episode, 1996'),
#  ('Stephen J. Turnbull', 'Fore Shadow Officer 1 episode, 1996'),
#  ('Andrew Smith', 'Cleric 1 episode, 1996'),
#  ('Janice Evens', 'Computer 1 episode, 1996'),
#  ('Marty Simon', 'Brain No. 14 1 episode, 1996'),
#  ('Elizabeth Richardson', 'Holo Prosecutor 1 episode, 1996-1997'),
#  ('Joseph Rutten', 'Slab Prisoner 1 episode, 1996'),
#  ('Chris Rowntree', 'Holo Official 1 episode, 1996'),
#  ('Rutger Hauer', 'Bog 1 episode, 1997'),
#  ('Doreen Jacobi', 'Wist 1 episode, 1997'),
#  ('Darcy Lindzon', 'Air Force One Attendant 1 episode, 2002'),
#  ('David Alexander Miller',
#   "Duke's Guard / ... (uncredited) 2 episodes, 1999-2000"),
#  ('J. William Grantham', 'ATF Agent (uncredited) 2 episodes, 2001'),
#  ('Rick Courtney', '790 (uncredited) 1 episode, 1996'),
#  ('Alexander Baier', 'Additional Girl (uncredited) 1 episode, 2000'),
#  ('Craig Dawson', 'Klassp (uncredited) 1 episode, 2000'),
#  ('Nikki McLean', 'Background (uncredited) 1 episode, 2001'),
#  ('Hank White', 'French Diplomat (uncredited) 1 episode, 2001')]
# [{'actor': 'Brian Downey',
#   'character': 'Stanley H. Tweedle / ... 61 episodes, 1996-2002'},
#  {'actor': 'Michael McManus', 'character': 'Kai / ... 61 episodes, 1996-2002'},
#  {'actor': 'Jeffrey Hirschfield',
#   'character': '790 / ... 57 episodes, 1996-2002'},
#  {'actor': 'Xenia Seeberg',
#   'character': 'Xev Bellringer / ... 55 episodes, 1998-2002'},
#  {'actor': 'Tom Gallant', 'character': 'The Lexx 46 episodes, 1996-2002'},
#  {'actor': 'Nigel Bennett', 'character': 'Prince / ... 23 episodes, 2000-2002'},
#  {'actor': 'Patricia Zentilli',
#   'character': 'Bunny Priest / ... 16 episodes, 1999-2002'},
#  {'actor': 'Lex Gigeroff',
#   'character': 'Bound Man / ... 8 episodes, 1996-2002'},
#  {'actor': 'Rolf Kanies',
#   'character': 'Reginald J. Priest / ... 13 episodes, 2000-2002'},
#  {'actor': 'Louise Wischermann',
#   'character': 'Lyekka / ... 10 episodes, 1998-2002'},
#  {'actor': 'John Dunsworth',
#   'character': 'Divine Predecessor / ... 7 episodes, 1996-2002'},
#  {'actor': 'Walter Borden',
#   'character': 'His Divine Shadow / ... 8 episodes, 1996-2002'},
#  {'actor': 'David Albiston',
#   'character': 'Mothbreeder / ... 3 episodes, 1998-2002'},
#  {'actor': 'Minna Aaltonen', 'character': 'Vlad / ... 5 episodes, 2001-2002'},
#  {'actor': 'Clive Sweeney',
#   'character': 'Megashadow Adjutant / ... 6 episodes, 1996-2000'},
#  {'actor': 'Eva Habermann',
#   'character': 'Zev Bellringer 7 episodes, 1996-2000'},
#  {'actor': 'Ellen Dubin', 'character': 'Giggerota / ... 7 episodes, 1996-2002'},
#  {'actor': 'Anna Cameron',
#   'character': 'The Time Prophet / ... 5 episodes, 1996-2002'},
#  {'actor': 'Dieter Laser', 'character': 'Mantrid 5 episodes, 1998-2000'},
#  {'actor': 'Jeff Pustil', 'character': 'Fifi / ... 6 episodes, 1999-2001'},
#  {'actor': 'David McClelland',
#   'character': 'Holo Cleric / ... 5 episodes, 1996-2001'},
#  {'actor': 'Kevin Curran', 'character': 'Dougall 4 episodes, 2001-2002'},
#  {'actor': 'Jamie Bradley', 'character': 'Jood / ... 5 episodes, 1996-2001'},
#  {'actor': 'Jeremy Akerman',
#   'character': 'Transport Major / ... 5 episodes, 1996-1999'},
#  {'actor': 'Nicolás Artajo', 'character': 'Child / ... 5 episodes, 1996-1999'},
#  {'actor': 'John Dartt', 'character': 'Holo Lawyr / ... 5 episodes, 1996-2002'},
#  {'actor': 'Chas Lawther',
#   'character': 'Video Customs Officer / ... 5 episodes, 1996-2001'},
#  {'actor': 'Todd Godin', 'character': 'Mothbreeder / ... 1 episode, 2000-2002'},
#  {'actor': 'Robert Sigl', 'character': 'Petrif / ... 4 episodes, 1996-2000'},
#  {'actor': 'David Renton', 'character': 'Joshua / ... 4 episodes, 1996-2000'},
#  {'actor': 'Lionel Doucette',
#   'character': 'Holo Judge / ... 4 episodes, 1996-1999'},
#  {'actor': 'Ralph Brown', 'character': 'Duke 5 episodes, 2000'},
#  {'actor': 'Anna Kathrin Bleuler', 'character': 'May 5 episodes, 2000'},
#  {'actor': 'Tony Anholt', 'character': 'Anchorman / ... 4 episodes, 2001-2002'},
#  {'actor': 'Tara Doyle', 'character': 'Tina 4 episodes, 2001-2002'},
#  {'actor': 'Gary Levert',
#   'character': 'Lead Balloonist / ... 4 episodes, 2000-2002'},
#  {'actor': 'Jon K. Loverin',
#   'character': 'Handler 2 / ... 4 episodes, 1999-2001'},
#  {'actor': 'Glenn Wadman',
#   'character': 'Archaeologist / ... 4 episodes, 1996-2002'},
#  {'actor': 'Jennifer Overton',
#   'character': 'Matron / ... 3 episodes, 1997-2000'},
#  {'actor': 'Geoff Herod', 'character': 'Brock / ... 3 episodes, 2000-2001'},
#  {'actor': 'Glen Grant',
#   'character': 'Blue Team Member / ... 1 episode, 2000-2002'},
#  {'actor': 'Richard Donat',
#   'character': 'Megashadow Admiral 4 episodes, 1996-1997'},
#  {'actor': 'Gil Brenton', 'character': 'Tem 4 episodes, 1996-1997'},
#  {'actor': 'Barbara Kowa', 'character': 'Wig Girl 4 episodes, 1996-1997'},
#  {'actor': 'Bill Carr',
#   'character': 'Correction Center Guard 4 episodes, 1996-1997'},
#  {'actor': 'Sanjay Talwar', 'character': 'Honar 4 episodes, 1996-1997'},
#  {'actor': 'Clemens von Tubeuf', 'character': 'Monk 4 episodes, 1996-1997'},
#  {'actor': 'Gary Vermeir', 'character': 'Scientist 4 episodes, 1996-1997'},
#  {'actor': 'Jocelyn Cunningham',
#   'character': 'Cluster Major 4 episodes, 1996-1997'},
#  {'actor': 'Andrei Mahankov', 'character': 'Rebel 4 episodes, 1996-1997'},
#  {'actor': 'Stephen McHattie',
#   'character': 'E.J. Moss, Commander of Eagle 5 / ... 3 episodes, 1998-2002'},
#  {'actor': 'Ryan Cooley', 'character': 'Digby 3 episodes, 2001'},
#  {'actor': 'Mark A. Owen',
#   'character': 'Big Angry Ed / ... 3 episodes, 1999-2001'},
#  {'actor': 'Janet Wright',
#   'character': 'First Lady Priest / ... 2 episodes, 1999-2001'},
#  {'actor': 'Geoff McBride',
#   'character': 'Moth Breeder / ... 2 episodes, 2001-2002'},
#  {'actor': 'Jenson Vaughan', 'character': 'Moth Breeder 2 episodes, 2001-2002'},
#  {'actor': 'Louis Del Grande',
#   'character': 'Louie / ... 2 episodes, 1999-2002'},
#  {'actor': 'Brandon McCarvell', 'character': 'Norb / ... 2 episodes, 1999'},
#  {'actor': 'Holger Kunkel', 'character': 'Boork / ... 2 episodes, 1997-1998'},
#  {'actor': 'Andrea Green',
#   'character': 'Davinia Silver / ... 2 episodes, 2001'},
#  {'actor': 'Lauren Abrahams', 'character': 'Lomea / ... 2 episodes, 1999-2001'},
#  {'actor': 'Brian Carter', 'character': '791 / ... 2 episodes, 1999-2002'},
#  {'actor': 'Linda Busby', 'character': 'Chief Handler 2 episodes, 2000'},
#  {'actor': 'Peter Guinness',
#   'character': 'Joseph Van Helsing 2 episodes, 2001'},
#  {'actor': 'Stephen Coats', 'character': 'Dad / ... 2 episodes, 2001'},
#  {'actor': 'Angie Hill', 'character': 'Muffy / ... 2 episodes, 2001'},
#  {'actor': 'Dan Fredenburgh', 'character': 'Gordon 2 episodes, 2002'},
#  {'actor': 'Laura Mae Nason',
#   'character': 'Dream Girl #2 / ... 2 episodes, 1999'},
#  {'actor': 'Chris Duffy',
#   'character': 'ATF Agent #1 / ... 2 episodes, 1998-2001'},
#  {'actor': 'Marem Hassler', 'character': 'Skankita 2 episodes, 2002'},
#  {'actor': 'Michael Pellerin',
#   'character': 'Road Worker / ... 2 episodes, 1999-2002'},
#  {'actor': 'Landy Cannon', 'character': 'Root / ... 2 episodes, 2000-2002'},
#  {'actor': 'Rachel Mooney',
#   'character': 'Mandragora Morgana / ... 2 episodes, 2001'},
#  {'actor': 'Stephen J.M. Sisk',
#   'character': 'Flintokk, Head Pimp Sister / ... 2 episodes, 1999-2000'},
#  {'actor': 'Andre Haines', 'character': 'Doily / ... 2 episodes, 1999-2000'},
#  {'actor': 'Alan MacGillivray',
#   'character': 'Argon Protopi / ... 2 episodes, 1996-1999'},
#  {'actor': 'Shaun Clarke', 'character': 'Reteep / ... 2 episodes, 1997'},
#  {'actor': 'Graham Pountney',
#   'character': 'Commentator / ... 2 episodes, 2001-2002'},
#  {'actor': 'Sam White', 'character': 'Rexal / ... 2 episodes, 1999-2001'},
#  {'actor': 'Andy Smith',
#   'character': 'Eco Tourist #2 / ... 2 episodes, 1999-2001'},
#  {'actor': 'Angela Vermeir',
#   'character': 'Computer / ... 2 episodes, 1999-2001'},
#  {'actor': 'Jack Carr', 'character': 'Bellhop / ... 2 episodes, 1996-2002'},
#  {'actor': 'Sherry White',
#   'character': 'Middle aged woman / ... 2 episodes, 1999-2001'},
#  {'actor': 'Mike Petersen',
#   'character': '790 Robot / ... 2 episodes, 1996-1997'},
#  {'actor': 'Maury Chaykin', 'character': 'Pa Gollean / ... 1 episode, 1999'},
#  {'actor': 'Lisa Hynes',
#   'character': 'Original Xev / ... 2 episodes, 1996-2000'},
#  {'actor': 'Malcolm Younger', 'character': 'Priest / ... 1 episode, 2000'},
#  {'actor': 'Amy Kerr', 'character': 'Desh / ... 1 episode, 1999-2002'},
#  {'actor': 'Jeri-Matti Helppi', 'character': 'Peasant 1 episode, 2001'},
#  {'actor': 'Cindy Sampson',
#   'character': 'Druid Girl / ... 1 episode, 1999-2001'},
#  {'actor': 'Joshua Young',
#   'character': 'Black Pawn #3 / ... 1 episode, 2001-2002'},
#  {'actor': 'Tom Tasse', 'character': 'C.G. 1 episode, 1999'},
#  {'actor': 'Gordon Patrick White',
#   'character': 'Thief / ... 1 episode, 1999-2001'},
#  {'actor': 'Simon Licht', 'character': 'Dr. Kazan 1 episode, 1998'},
#  {'actor': 'Lenore Zann', 'character': 'The Dark Lady 1 episode, 1999'},
#  {'actor': 'Page Fletcher', 'character': 'Captain Jebbed 1 episode, 1999'},
#  {'actor': 'Nina Franoszek',
#   'character': 'Grand Prosecutor Jihana 1 episode, 1999'},
#  {'actor': 'Earl Pastko', 'character': 'Brizon 1 episode, 1999'},
#  {'actor': 'Andrew Bigelow', 'character': 'Enox 1 episode, 1999'},
#  {'actor': 'Matthew Burton', 'character': 'Brother Randor 1 episode, 1999'},
#  {'actor': 'Jeremy Webb', 'character': 'Master of Ceremonies 1 episode, 1999'},
#  {'actor': 'Richard Braine',
#   'character': 'Card Carrying Druid 1 episode, 2001'},
#  {'actor': 'Nick Cawdron', 'character': 'Deputy Festus Trout 1 episode, 2002'},
#  {'actor': 'Tim Curry', 'character': 'Poet Man 1 episode, 1997'},
#  {'actor': 'Andy Jones', 'character': 'Smoor 1 episode, 1997'},
#  {'actor': 'Wayne Robson', 'character': 'Gubby Mok 1 episode, 1999'},
#  {'actor': 'Mary Walsh', 'character': 'Heedia 1 episode, 1999'},
#  {'actor': 'Andrew Bush', 'character': 'Tad 1 episode, 1999'},
#  {'actor': 'Susan Quinn', 'character': 'Sissy Gollean 1 episode, 1999'},
#  {'actor': 'Diego Chambers', 'character': 'Aulk 1 episode, 1999'},
#  {'actor': 'Matthias Klimsa', 'character': 'Brother Treygor 1 episode, 1999'},
#  {'actor': 'Barbara Schmied', 'character': 'Slinka 1 episode, 1999'},
#  {'actor': 'Polly Jo Pleasence', 'character': 'Rivet 1 episode, 2000'},
#  {'actor': 'Julia Haacke', 'character': 'Lily 1 episode, 2000'},
#  {'actor': 'David Christoffel', 'character': 'Cellphone Druid 1 episode, 2001'},
#  {'actor': 'Britt Ekland',
#   'character': 'Dulcibella Sternflanks 1 episode, 2002'},
#  {'actor': 'Polly Green', 'character': 'Amber 1 episode, 2002'},
#  {'actor': 'Kathryn Fraser', 'character': 'Bereaved Mom 1 episode, 2002'},
#  {'actor': 'Sandra Keller', 'character': 'Nurse / ... 1 episode, 1999'},
#  {'actor': 'Dave Carmichael', 'character': 'Junior Gollean 1 episode, 1999'},
#  {'actor': 'Sharon Timmins', 'character': 'Groo 1 episode, 1999'},
#  {'actor': 'Sandra S. Leonhard', 'character': 'Tish 1 episode, 2000'},
#  {'actor': 'Terry Neason', 'character': 'Wench 1 episode, 2000'},
#  {'actor': 'Hephzibah Tintner', 'character': 'Tulip 1 episode, 2000'},
#  {'actor': 'Nicole Ciroth', 'character': 'Minx 1 episode, 2000'},
#  {'actor': 'Nick Ewans', 'character': 'Colin 1 episode, 2001'},
#  {'actor': 'Michael Best', 'character': 'Merle 1 episode, 2001'},
#  {'actor': 'Celia Henebury', 'character': 'Didi Figgleshrick 1 episode, 2002'},
#  {'actor': 'Mason Phillips', 'character': 'Wyatt 1 episode, 2002'},
#  {'actor': 'Donald Chisholm', 'character': 'FBI Lieutenant 1 episode, 2002'},
#  {'actor': 'Barry Bostwick', 'character': 'Thodin 1 episode, 1996'},
#  {'actor': 'Malcolm McDowell', 'character': 'Yottskry 1 episode, 1997'},
#  {'actor': 'Gerry Wolff', 'character': 'Snik 1 episode, 1997'},
#  {'actor': 'Kate Rose', 'character': 'Holo Woman 1 episode, 1997'},
#  {'actor': 'Roman Podhora', 'character': 'L.L. Boosh 1 episode, 1998'},
#  {'actor': 'Oliver Stern', 'character': 'Dr. Funz 1 episode, 1998'},
#  {'actor': 'Benjamin Sadler', 'character': 'Nool 1 episode, 1999'},
#  {'actor': 'Ellen-Ray Hennessy', 'character': 'Rissha 1 episode, 1999'},
#  {'actor': 'Nikki Barnett', 'character': 'Kanana 1 episode, 1999'},
#  {'actor': 'Kerry McPherson', 'character': 'Skye 1 episode, 1999'},
#  {'actor': 'Paul McQuillan', 'character': 'Kyoo 1 episode, 1999'},
#  {'actor': 'Diane Langton', 'character': 'Hammer 1 episode, 2000'},
#  {'actor': 'Urs Remond', 'character': 'Cab 1 episode, 2000'},
#  {'actor': 'Udo Jolly', 'character': 'Dr. Bunz 1 episode, 2000'},
#  {'actor': 'Sabrina Rattey', 'character': 'Daisy 1 episode, 2000'},
#  {'actor': 'Peter Blake', 'character': 'Oliver 1 episode, 2001'},
#  {'actor': 'Tim Frances', 'character': 'Puck 1 episode, 2001'},
#  {'actor': 'Howard Attfield', 'character': 'Executive 1 episode, 2001'},
#  {'actor': 'Agumeuay Nakanakis',
#   'character': 'Native American Leader 1 episode, 2001'},
#  {'actor': 'Danielle Dawe', 'character': 'Tourist 1 episode, 2001'},
#  {'actor': 'Lois Brown', 'character': 'Older Woman 1 episode, 2001'},
#  {'actor': 'Johnny Lomas', 'character': 'Josh 1 episode, 2002'},
#  {'actor': 'Andrulla Blanchette',
#   'character': 'Queen of Sheba 1 episode, 2002'},
#  {'actor': 'John Diamond', 'character': 'Burl 1 episode, 2002'},
#  {'actor': 'Rachel Grover', 'character': "Zev's Mother 1 episode, 1997"},
#  {'actor': 'Barbara Geiger', 'character': 'Dr. Veezra 1 episode, 1998'},
#  {'actor': 'David Lewis', 'character': 'Fruitcake 1 episode, 1999-2000'},
#  {'actor': 'Stacy Smith', 'character': 'Calico 1 episode, 1999'},
#  {'actor': 'Susanna Metzner', 'character': 'Lissha 1 episode, 1999'},
#  {'actor': 'Martin Höner', 'character': 'Older Brother 1 episode, 1999'},
#  {'actor': 'Bruce Fillmore', 'character': 'Gibble 1 episode, 1999'},
#  {'actor': 'Joe Wynn', 'character': 'New Born 1 episode, 1999'},
#  {'actor': 'Ina Paule Klink', 'character': 'Daffodil 1 episode, 2000'},
#  {'actor': 'Jelena Budimir', 'character': 'Socket 1 episode, 2000'},
#  {'actor': 'Hans Brückner', 'character': 'Zin 1 episode, 2000'},
#  {'actor': 'Katrin Schrake', 'character': 'Fox 1 episode, 2000'},
#  {'actor': 'Craig Charles', 'character': 'The Warden 1 episode, 2001'},
#  {'actor': 'Jay Benedict', 'character': 'Vet 1 episode, 2001'},
#  {'actor': 'Brian Buckley', 'character': 'George 1 episode, 2001'},
#  {'actor': 'Alexis Conran', 'character': 'Mustafa Al Hambra 1 episode, 2001'},
#  {'actor': 'Bob Dearden', 'character': 'Dale 1 episode, 2001'},
#  {'actor': 'Patrick Gordon', 'character': 'Oberon 1 episode, 2001'},
#  {'actor': 'Rupert Evans', 'character': 'Cleasby 1 episode, 2002'},
#  {'actor': 'Rebecca Mordan', 'character': 'Haley 1 episode, 2002'},
#  {'actor': 'Kevin Deagle', 'character': 'A.F.R. #1 1 episode, 2002'},
#  {'actor': 'Hussi Kutlucan', 'character': 'Orlluk 1 episode, 1997'},
#  {'actor': 'Eva Ebner', 'character': 'Mrs. Deebee 1 episode, 1998'},
#  {'actor': 'Burgandy Code', 'character': 'Navigator 1 episode, 1998'},
#  {'actor': 'Tom Petry Strauss', 'character': 'Brother Deal 1 episode, 1999'},
#  {'actor': 'Peter Scollin', 'character': 'Guard 1 1 episode, 1999'},
#  {'actor': 'Lee-Anne Lowe', 'character': 'Dream Girl #1 1 episode, 1999'},
#  {'actor': 'Karl Lewis Johnston', 'character': 'Glootus 1 episode, 1999'},
#  {'actor': 'Robin Johnson', 'character': 'Guard #1 1 episode, 1999'},
#  {'actor': 'Rosemarie Friedrich', 'character': 'The Wife 1 episode, 1999'},
#  {'actor': 'Katja Richter', 'character': 'Lynx 1 episode, 2000'},
#  {'actor': 'David Matheson', 'character': 'ATF Agent 1 episode, 2001'},
#  {'actor': 'Rejean Cournoyer', 'character': 'Earl 1 episode, 2001'},
#  {'actor': 'David Charles', 'character': 'Boy 1 episode, 2001'},
#  {'actor': 'Mike Daly', 'character': 'ATF Agent 1 episode, 2001'},
#  {'actor': 'Stan Carew', 'character': 'French Diplomat 1 episode, 2001'},
#  {'actor': 'Karen Beverly', 'character': 'Journalist #2 1 episode, 2001'},
#  {'actor': 'Giovanni del Vecchio', 'character': 'Marconi 1 episode, 2001'},
#  {'actor': 'Togo Igawa', 'character': 'Monk 1 episode, 2002'},
#  {'actor': 'Finlay Robertson', 'character': 'Ryan 1 episode, 2002'},
#  {'actor': 'Rory MacGregor', 'character': 'Mort the Mortician 1 episode, 2002'},
#  {'actor': 'Doug Barron', 'character': 'Secretary of Defense 1 episode, 2002'},
#  {'actor': 'Shawn Duggan', 'character': 'Survivalist #2 1 episode, 2002'},
#  {'actor': 'Dennis Envoldsen',
#   'character': 'Corporal Harrison Birdie 1 episode, 2002'},
#  {'actor': 'Hans-Dieter Brückner', 'character': 'Grullek 1 episode, 1997'},
#  {'actor': 'Errol Shaker', 'character': 'Administrator 1 episode, 1998'},
#  {'actor': 'John Davie', 'character': 'Rockhound 1 episode, 1998'},
#  {'actor': 'Noah Dalton Danby', 'character': 'Varrtan 1 episode, 1999'},
#  {'actor': 'C.J. Lusby', 'character': 'Nympho 1 1 episode, 1999'},
#  {'actor': 'Harvey Friedman', 'character': 'Guard 3 1 episode, 1999'},
#  {'actor': 'Christian Murray', 'character': '792 1 episode, 1999'},
#  {'actor': 'Lorraine Segato', 'character': 'Time Prophet 1 episode, 1999'},
#  {'actor': 'Philippe Roche',
#   'character': 'Brother Stack / ... 1 episode, 1999'},
#  {'actor': 'Christian Murray', 'character': 'Gold Lamé Man 1 episode, 1999'},
#  {'actor': 'Jimmy Somerville', 'character': 'Satin 1 episode, 2000'},
#  {'actor': 'Rose Zone', 'character': 'Bruise 1 episode, 2000'},
#  {'actor': 'Clive Merrison', 'character': 'Professor Shnoog 1 episode, 2001'},
#  {'actor': 'Alun Lewis',
#   'character': 'Uther de Glastonbury, formerly known as Nigel Bumsen 1 '
#                'episode, 2001'},
#  {'actor': 'John Gleeson', 'character': 'Doctor 1 episode, 2001'},
#  {'actor': 'David Francis', 'character': 'Newfie 1 episode, 2001'},
#  {'actor': 'Lee J. Campbell', 'character': 'Journalist #1 1 episode, 2001'},
#  {'actor': 'Melanie Harris', 'character': 'Marjorie 1 episode, 2001'},
#  {'actor': 'James Crossley', 'character': 'Chad 1 episode, 2001'},
#  {'actor': 'Philip Dinn', 'character': 'Local 1 episode, 2001'},
#  {'actor': 'Seán Cullen', 'character': 'Remo 1 episode, 2002'},
#  {'actor': 'Richard Hanson', 'character': 'Devlin 1 episode, 2002'},
#  {'actor': 'Geoffrey McLean', 'character': 'Middle Aged Son 1 episode, 2002'},
#  {'actor': 'Rainer Matsutani',
#   'character': 'Brunnen-G General 1 episode, 1997'},
#  {'actor': 'Arno Wyzniewski', 'character': 'Kuk 1 episode, 1997'},
#  {'actor': 'Ian T. Dickinson', 'character': 'Berg 1 episode, 1998'},
#  {'actor': 'Milton Welsh', 'character': 'Rat II 1 episode, 1999'},
#  {'actor': 'Thorsten Feller', 'character': 'Liggum 1 episode, 1999'},
#  {'actor': 'Amy Lonergan', 'character': 'Dream Girl #3 1 episode, 1999'},
#  {'actor': 'Alison McMullin', 'character': 'Nympho 2 1 episode, 1999'},
#  {'actor': 'Paul Day', 'character': 'Consort 1 episode, 1999'},
#  {'actor': 'Dick Sircom', 'character': 'Judge 1 episode, 1999'},
#  {'actor': 'Adrienne Horton', 'character': 'Guard #3 1 episode, 1999'},
#  {'actor': 'Peter Baylis', 'character': 'First Balloonist 1 episode, 2000'},
#  {'actor': 'Lionel Jeffries', 'character': 'Father Borscht 1 episode, 2001'},
#  {'actor': 'Mick Walter', 'character': 'Titania 1 episode, 2001'},
#  {'actor': 'Jim Fowler', 'character': 'Rooster 1 episode, 2001'},
#  {'actor': 'Ken Shipley', 'character': 'Produce Manager 1 episode, 2001'},
#  {'actor': 'Tom Haney', 'character': 'Studio Guard 1 episode, 2001'},
#  {'actor': 'Sam Douglas', 'character': 'General Klebstock 1 episode, 2002'},
#  {'actor': 'Mike Durling', 'character': 'Joey 1 episode, 2002'},
#  {'actor': 'Michael Habeck', 'character': 'Feppo 1 episode, 1997-1999'},
#  {'actor': 'Tatjana Alexander', 'character': 'Nurse 1 episode, 1998'},
#  {'actor': 'Gabi Fleming', 'character': 'Dead Female Body 1 episode, 1999'},
#  {'actor': 'Lori Heath', 'character': 'Hologram Guard 1 episode, 1999'},
#  {'actor': 'Adrian Mattiske',
#   'character': 'Young Copying Brother 1 episode, 1999'},
#  {'actor': 'Janaya Stephens', 'character': 'Peach 1 episode, 2000'},
#  {'actor': 'Keith-Lee Castle', 'character': 'Renfield 1 episode, 2001'},
#  {'actor': 'Jeremy Peters', 'character': 'Surgeon 1 episode, 2001'},
#  {'actor': 'Jason Hemsworth',
#   'character': 'Secret Service Agent 1 episode, 2001'},
#  {'actor': 'Andrea Dymond', 'character': 'Goth Prisoner 1 episode, 2001'},
#  {'actor': 'Michael J. Reynolds',
#   'character': 'Colonel Donald K. Gore 1 episode, 2002'},
#  {'actor': 'William Parsons', 'character': 'Older Husband 1 episode, 2002'},
#  {'actor': 'Nancy Marshall', 'character': 'Geekette 1 episode, 2002'},
#  {'actor': 'Rick Collins', 'character': 'Fat Man 1 episode, 1999'},
#  {'actor': 'Greg Cormier', 'character': 'Bound Man 1 episode, 1999'},
#  {'actor': 'Thomas Arnicke', 'character': 'Bodyguard 1 episode, 1999'},
#  {'actor': 'Wanja Mues', 'character': 'Pearl 1 episode, 2000'},
#  {'actor': 'Robyn Palmer', 'character': 'Pear 1 episode, 2000'},
#  {'actor': 'Martha Irving', 'character': 'Doris 1 episode, 2001'},
#  {'actor': 'Travis Ferris', 'character': 'Guard #2 1 episode, 2001'},
#  {'actor': 'Kevin LeBlanc', 'character': 'FBI Agent #1 1 episode, 2002'},
#  {'actor': 'Mary Alvena Poole', 'character': 'Older Wife 1 episode, 2002'},
#  {'actor': 'Paul Jessen', 'character': 'ATF Officer 1 episode, 2002'},
#  {'actor': 'Jim Petrie', 'character': 'Gorrett 1 episode, 1997'},
#  {'actor': 'Terry Nicholas', 'character': 'First Babe 1 episode, 1999'},
#  {'actor': 'Al Mueller', 'character': 'Bodyguard 1 episode, 1999'},
#  {'actor': 'Roberta Angelica', 'character': 'Plum 1 episode, 2000'},
#  {'actor': 'Roger Tebb', 'character': 'Silk 1 episode, 2000'},
#  {'actor': 'Robert Maillet', 'character': 'Leroy 1 episode, 2001'},
#  {'actor': 'Frank Kelly', 'character': 'Father Pickle 1 episode, 2001'},
#  {'actor': 'Richard Hards', 'character': 'Nelson 1 episode, 2001'},
#  {'actor': 'Arthur Spray', 'character': 'Gypsy Servant 1 episode, 2001'},
#  {'actor': 'Bill Jessome', 'character': 'Chief Justice 1 episode, 2001'},
#  {'actor': 'Kelsa Kinsly', 'character': 'Slave Girl 88 1 episode, 2002'},
#  {'actor': 'Jesse Lund', 'character': 'Rod 1 episode, 2002'},
#  {'actor': 'Stephanie Redding', 'character': 'Twin Daughter 1 episode, 2002'},
#  {'actor': 'Sherry Devanney', 'character': 'Kyyra 1 episode, 1997'},
#  {'actor': 'Lisa Wong', 'character': 'Second Babe 1 episode, 1999'},
#  {'actor': 'Dave Maddeaux', 'character': 'Male Customer 1 episode, 1999'},
#  {'actor': 'Mirko Szabo', 'character': 'Bodyguard 1 episode, 1999'},
#  {'actor': 'Mika Ward', 'character': 'Cherry 1 episode, 2000'},
#  {'actor': 'Georg Tryphon', 'character': 'Lace 1 episode, 2000'},
#  {'actor': 'John Standing', 'character': 'Count Dracul 1 episode, 2001'},
#  {'actor': 'Chris Owens', 'character': 'Biff 1 episode, 2001'},
#  {'actor': 'Hattie Hayridge', 'character': 'Sub-Warden Heidi 1 episode, 2001'},
#  {'actor': 'Bette MacDonald', 'character': 'Marge 1 episode, 2001'},
#  {'actor': 'Madeleine Lefebvre', 'character': 'Eco Tourist #1 1 episode, 2001'},
#  {'actor': 'Gareth Miller', 'character': 'Lieutenant 1 episode, 2001'},
#  {'actor': 'John Lebar', 'character': 'The Mummy - Draco 1 episode, 2002'},
#  {'actor': 'Ryan McCluskey', 'character': 'Tad 1 episode, 2002'},
#  {'actor': 'Nicole Redding', 'character': 'Dead Twin Daughter 1 episode, 2002'},
#  {'actor': 'Cleveland Sauer', 'character': 'Survivalist 1 episode, 2002'},
#  {'actor': 'Joel Sapp', 'character': 'Bleeding Cleric / ... 1 episode, 1997'},
#  {'actor': 'Sebastian Kokot', 'character': 'Bodyguard 1 episode, 1999'},
#  {'actor': 'Renate Spona', 'character': 'Guard #1 1 episode, 2000'},
#  {'actor': 'Ed Macdonald', 'character': 'Leo 1 episode, 2001'},
#  {'actor': 'Maggie Holland', 'character': 'Elderly Lady 1 episode, 2001'},
#  {'actor': 'Nunzio Lombardo', 'character': 'Valentino 1 episode, 2001'},
#  {'actor': 'Stephen Morgan', 'character': 'Chip 1 episode, 2001'},
#  {'actor': 'Dan Steeves', 'character': 'Store Guard 1 episode, 2001'},
#  {'actor': 'Marguerite McNeil',
#   'character': 'Stress Counselor 1 episode, 2002'},
#  {'actor': 'Dominic Pallotta', 'character': 'Frankie 1 episode, 2002'},
#  {'actor': 'Oliver Stolz', 'character': 'Bodyguard 1 episode, 1999'},
#  {'actor': 'Sabine Winterfeldt', 'character': 'Guard #2 1 episode, 2000'},
#  {'actor': "Ross O'Hennessy", 'character': 'Cedric 1 episode, 2001'},
#  {'actor': 'Alec Linstead',
#   'character': 'Cardinal Meinpo Duftet 1 episode, 2001'},
#  {'actor': 'Douglas Mayr', 'character': 'Bartender 1 episode, 2001'},
#  {'actor': 'James Reeve', 'character': 'Sheriff 1 episode, 2001'},
#  {'actor': 'Laura Patch', 'character': 'Piccalina 1 episode, 2002'},
#  {'actor': 'Jeremiah Sparks', 'character': 'Cabbie 1 episode, 2002'},
#  {'actor': 'Thordis König', 'character': 'Guard #3 1 episode, 2000'},
#  {'actor': 'David Verrey', 'character': 'Businessman 1 episode, 2001'},
#  {'actor': 'Justin Pierre', 'character': 'Bob 1 episode, 2001'},
#  {'actor': 'Rhonda McLean', 'character': 'Mom 1 episode, 2001'},
#  {'actor': 'Julia Moore', 'character': 'Truro 1 episode, 2001'},
#  {'actor': 'Lydia Klenck', 'character': 'Shower Nude #1 1 episode, 2001'},
#  {'actor': 'Tricia Taylor', 'character': 'Love Slave Wrestler 1 episode, 2002'},
#  {'actor': 'Jason Sweeney', 'character': 'Rex 1 episode, 2002'},
#  {'actor': 'Lenuta Sim', 'character': 'Dancing Twin #2 1 episode, 1997'},
#  {'actor': 'Gina Fischer', 'character': 'Guard #4 1 episode, 2000'},
#  {'actor': 'Craig Wood', 'character': 'Chief Guard 1 episode, 2000'},
#  {'actor': 'Silvio Simac', 'character': 'Hank 1 episode, 2001'},
#  {'actor': 'Heather Rankin', 'character': 'Phoebe 1 episode, 2001'},
#  {'actor': 'John Pearson', 'character': 'Cobra 1 episode, 2001'},
#  {'actor': 'Beth Mahaney', 'character': 'Shower Nude #2 1 episode, 2001'},
#  {'actor': 'Bruce Murphy', 'character': 'Junior 1 episode, 2001'},
#  {'actor': 'Heidi von Palleske', 'character': 'Slave Girl 24 1 episode, 2002'},
#  {'actor': 'Matt Zimmerman', 'character': 'Supervisor 1 episode, 2002'},
#  {'actor': 'Mariana Sim', 'character': 'Dancing Twin #1 1 episode, 1997'},
#  {'actor': 'Jana Piehl', 'character': 'Guard #5 1 episode, 2000'},
#  {'actor': 'Jamie Sparks', 'character': 'Passenger 1 episode, 2001'},
#  {'actor': 'Peter James', 'character': 'Guard #1 1 episode, 2001'},
#  {'actor': 'Raymond Solomon', 'character': 'Jacques 1 episode, 2001'},
#  {'actor': 'Maisie Rillie', 'character': 'Sharon 1 episode, 2001'},
#  {'actor': 'Andy Gatjen', 'character': 'Ridolan 1 episode, 2001'},
#  {'actor': 'Shooglenifty', 'character': 'Themselves 1 episode, 2001'},
#  {'actor': 'Rupert Solomon', 'character': 'Pierce 1 episode, 2001'},
#  {'actor': 'Marcos Troy', 'character': 'Malik 1 episode, 2001'},
#  {'actor': 'Malcolm Cosbie', 'character': 'Self - Band 1 episode, 2001'},
#  {'actor': 'David Woods', 'character': 'Yoyal 1 episode, 1997'},
#  {'actor': 'Georgia Zaris', 'character': "Farley's Assistant 1 episode, 2001"},
#  {'actor': 'Jim Swansburg', 'character': 'Cmdr. Bricklin 1 episode, 2001'},
#  {'actor': 'Garry Finlayson', 'character': 'Self - Band 1 episode, 2001'},
#  {'actor': 'Craig Gaskin', 'character': 'Self - Band 1 episode, 2001'},
#  {'actor': 'Josh MacDonald', 'character': 'Sergeant 1 episode, 1996'},
#  {'actor': 'Angus Grant', 'character': 'Self - Band 1 episode, 2001'},
#  {'actor': 'Ian MacLeod', 'character': 'Self - Band 1 episode, 2001'},
#  {'actor': 'Conrad Molleson', 'character': 'Self - Band 1 episode, 2001'},
#  {'actor': 'Horst Ulan', 'character': 'Cluster General 1 episode, 1996'},
#  {'actor': 'Stephen J. Turnbull',
#   'character': 'Fore Shadow Officer 1 episode, 1996'},
#  {'actor': 'Andrew Smith', 'character': 'Cleric 1 episode, 1996'},
#  {'actor': 'Janice Evens', 'character': 'Computer 1 episode, 1996'},
#  {'actor': 'Marty Simon', 'character': 'Brain No. 14 1 episode, 1996'},
#  {'actor': 'Elizabeth Richardson',
#   'character': 'Holo Prosecutor 1 episode, 1996-1997'},
#  {'actor': 'Joseph Rutten', 'character': 'Slab Prisoner 1 episode, 1996'},
#  {'actor': 'Chris Rowntree', 'character': 'Holo Official 1 episode, 1996'},
#  {'actor': 'Rutger Hauer', 'character': 'Bog 1 episode, 1997'},
#  {'actor': 'Doreen Jacobi', 'character': 'Wist 1 episode, 1997'},
#  {'actor': 'Darcy Lindzon',
#   'character': 'Air Force One Attendant 1 episode, 2002'},
#  {'actor': 'David Alexander Miller',
#   'character': "Duke's Guard / ... (uncredited) 2 episodes, 1999-2000"},
#  {'actor': 'J. William Grantham',
#   'character': 'ATF Agent (uncredited) 2 episodes, 2001'},
#  {'actor': 'Rick Courtney', 'character': '790 (uncredited) 1 episode, 1996'},
#  {'actor': 'Alexander Baier',
#   'character': 'Additional Girl (uncredited) 1 episode, 2000'},
#  {'actor': 'Craig Dawson', 'character': 'Klassp (uncredited) 1 episode, 2000'},
#  {'actor': 'Nikki McLean',
#   'character': 'Background (uncredited) 1 episode, 2001'},
#  {'actor': 'Hank White',
#   'character': 'French Diplomat (uncredited) 1 episode, 2001'}]

# %% [markdown]
# **Lab 3: Excercise 1 from PDF**
#
# Using what we learned from the textbook, define a simple SeriesActor class that defines state
# variables related to an actor in a TV series. Your SeriesActor class should define at least 3 "state"
# variables: name, character, episodes.
#
# • Provide an __init__(self, ...) method to initialize a new SeriesActor object with
# specific data values and a little code to test you class.
#
# • Add a __str__(self) method that returns a nicely formatted string representation of the
# object, plus a little code to test it.

# %%
class SeriesActor:

  def __init__(self, initActor, initCharacter, initEpisodes):
    'Initialize a new series actor object.'
    self.actor = initActor
    self.character = initCharacter
    self.episodes = initEpisodes

  def __str__(self):
    return 'name is ' + str(self.actor) + '\ncharacter is ' + str(self.character) + '\nnumber of episodes are ' + str(self.episodes) + '\n'

#Test
a = SeriesActor('bob', 'joe', 40)
print(a)
# Out:
# name is bob
# character is joe
# number of episodes are 40

# %% [markdown]
# **Lab 3: Excercise 2 from PDF**
#
# In lab 2 we used both a tuple and then a dictionary to define each series-actor record.
# Add a code cell that defines another list comprehension that builds each of the series-actor records as
# an object.
#
# • write a loop over your list of series-actor objects to print the character name of each. Notice
# Comp 215 Lab 3
# how the object dot-notation creates a "namespace" for the data items contained within.
#
# Answer the following questions in a text block below this code:
#
# • what advantage(s) does a class / object have over a simple tuple or dictionary for
# representing a record?
# • Is it possible to call the methods defined by a class in the “normal” way, where the object is
# simply passed as the first parameter? How? (May take some experimenting).

# %%
a = [SeriesActor( item['name'], returnCharacterName(item['asCharacter']), returnNumberOfEpisodes(item['asCharacter'])) for item in actors]

#Test
for i in a:
  print(i)

# Creating an object has the advantage of being much more organized and legible
# When one creates an object, one can set several attributes for the object
# and create algorithms to assign values to those attributes.
# One can later easily access those organized and labeled attributes using dot notation.
# Tuples and dictionaries are much less organized. 
# The data within tuples cannot be labeled or organized under a larger, 'object or class.'
# Dictionaries do allow some labeling of data such as 'keys.' 
# However, dictionaries cannot be organized under specific 'classes.'
# Both objects and dictionaries also cannot have their own defined functions, which objects can.
# Out:
# name is Brian Downey
# character is  Stanley H. Tweedle
# number of episodes are 61
#
# name is Michael McManus
# character is  Kai
# number of episodes are 61
#
# name is Jeffrey Hirschfield
# character is  790
# number of episodes are 57
#
# name is Xenia Seeberg
# character is  Xev Bellringer
# number of episodes are 55
#
# name is Tom Gallant
# character is  The Lexx 46 episodes, 1996-2002
# number of episodes are 46
#
# name is Nigel Bennett
# character is  Prince
# number of episodes are 23
#
# name is Patricia Zentilli
# character is  Bunny Priest
# number of episodes are 16
#
# name is Lex Gigeroff
# character is  Bound Man
# number of episodes are 8
#
# name is Rolf Kanies
# character is  Reginald J. Priest
# number of episodes are 13
#
# name is Louise Wischermann
# character is  Lyekka
# number of episodes are 10
#
# name is John Dunsworth
# character is  Divine Predecessor
# number of episodes are 7
#
# name is Walter Borden
# character is  His Divine Shadow
# number of episodes are 8
#
# name is David Albiston
# character is  Mothbreeder
# number of episodes are 3
#
# name is Minna Aaltonen
# character is  Vlad
# number of episodes are 5
#
# name is Clive Sweeney
# character is  Megashadow Adjutant
# number of episodes are 6
#
# name is Eva Habermann
# character is  Zev Bellringer 7 episodes, 1996-2000
# number of episodes are 7
#
# name is Ellen Dubin
# character is  Giggerota
# number of episodes are 7
#
# name is Anna Cameron
# character is  The Time Prophet
# number of episodes are 5
#
# name is Dieter Laser
# character is  Mantrid 5 episodes, 1998-2000
# number of episodes are 5
#
# name is Jeff Pustil
# character is  Fifi
# number of episodes are 6
#
# name is David McClelland
# character is  Holo Cleric
# number of episodes are 5
#
# name is Kevin Curran
# character is  Dougall 4 episodes, 2001-2002
# number of episodes are 4
#
# name is Jamie Bradley
# character is  Jood
# number of episodes are 5
#
# name is Jeremy Akerman
# character is  Transport Major
# number of episodes are 5
#
# name is Nicolás Artajo
# character is  Child
# number of episodes are 5
#
# name is John Dartt
# character is  Holo Lawyr
# number of episodes are 5
#
# name is Chas Lawther
# character is  Video Customs Officer
# number of episodes are 5
#
# name is Todd Godin
# character is  Mothbreeder
# number of episodes are 1
#
# name is Robert Sigl
# character is  Petrif
# number of episodes are 4
#
# name is David Renton
# character is  Joshua
# number of episodes are 4
#
# name is Lionel Doucette
# character is  Holo Judge
# number of episodes are 4
#
# name is Ralph Brown
# character is  Duke 5 episodes, 2000
# number of episodes are 2000
#
# name is Anna Kathrin Bleuler
# character is  May 5 episodes, 2000
# number of episodes are 2000
#
# name is Tony Anholt
# character is  Anchorman
# number of episodes are 4
#
# name is Tara Doyle
# character is  Tina 4 episodes, 2001-2002
# number of episodes are 4
#
# name is Gary Levert
# character is  Lead Balloonist
# number of episodes are 4
#
# name is Jon K. Loverin
# character is  Handler 2
# number of episodes are 4
#
# name is Glenn Wadman
# character is  Archaeologist
# number of episodes are 4
#
# name is Jennifer Overton
# character is  Matron
# number of episodes are 3
#
# name is Geoff Herod
# character is  Brock
# number of episodes are 3
#
# name is Glen Grant
# character is  Blue Team Member
# number of episodes are 1
#
# name is Richard Donat
# character is  Megashadow Admiral 4 episodes, 1996-1997
# number of episodes are 4
#
# name is Gil Brenton
# character is  Tem 4 episodes, 1996-1997
# number of episodes are 4
#
# name is Barbara Kowa
# character is  Wig Girl 4 episodes, 1996-1997
# number of episodes are 4
#
# name is Bill Carr
# character is  Correction Center Guard 4 episodes, 1996-1997
# number of episodes are 4
#
# name is Sanjay Talwar
# character is  Honar 4 episodes, 1996-1997
# number of episodes are 4
#
# name is Clemens von Tubeuf
# character is  Monk 4 episodes, 1996-1997
# number of episodes are 4
#
# name is Gary Vermeir
# character is  Scientist 4 episodes, 1996-1997
# number of episodes are 4
#
# name is Jocelyn Cunningham
# character is  Cluster Major 4 episodes, 1996-1997
# number of episodes are 4
#
# name is Andrei Mahankov
# character is  Rebel 4 episodes, 1996-1997
# number of episodes are 4
#
# name is Stephen McHattie
# character is  E.J. Moss, Commander of Eagle 5
# number of episodes are 3
#
# name is Ryan Cooley
# character is  Digby 3 episodes, 2001
# number of episodes are 2001
#
# name is Mark A. Owen
# character is  Big Angry Ed
# number of episodes are 3
#
# name is Janet Wright
# character is  First Lady Priest
# number of episodes are 2
#
# name is Geoff McBride
# character is  Moth Breeder
# number of episodes are 2
#
# name is Jenson Vaughan
# character is  Moth Breeder 2 episodes, 2001-2002
# number of episodes are 2
#
# name is Louis Del Grande
# character is  Louie
# number of episodes are 2
#
# name is Brandon McCarvell
# character is  Norb
# number of episodes are 1999
#
# name is Holger Kunkel
# character is  Boork
# number of episodes are 2
#
# name is Andrea Green
# character is  Davinia Silver
# number of episodes are 2001
#
# name is Lauren Abrahams
# character is  Lomea
# number of episodes are 2
#
# name is Brian Carter
# character is  791
# number of episodes are 2
#
# name is Linda Busby
# character is  Chief Handler 2 episodes, 2000
# number of episodes are 2000
#
# name is Peter Guinness
# character is  Joseph Van Helsing 2 episodes, 2001
# number of episodes are 2001
#
# name is Stephen Coats
# character is  Dad
# number of episodes are 2001
#
# name is Angie Hill
# character is  Muffy
# number of episodes are 2001
#
# name is Dan Fredenburgh
# character is  Gordon 2 episodes, 2002
# number of episodes are 2002
#
# name is Laura Mae Nason
# character is  Dream Girl #2
# number of episodes are 1999
#
# name is Chris Duffy
# character is  ATF Agent #1
# number of episodes are 2
#
# name is Marem Hassler
# character is  Skankita 2 episodes, 2002
# number of episodes are 2002
#
# name is Michael Pellerin
# character is  Road Worker
# number of episodes are 2
#
# name is Landy Cannon
# character is  Root
# number of episodes are 2
#
# name is Rachel Mooney
# character is  Mandragora Morgana
# number of episodes are 2001
#
# name is Stephen J.M. Sisk
# character is  Flintokk, Head Pimp Sister
# number of episodes are 2
#
# name is Andre Haines
# character is  Doily
# number of episodes are 2
#
# name is Alan MacGillivray
# character is  Argon Protopi
# number of episodes are 2
#
# name is Shaun Clarke
# character is  Reteep
# number of episodes are 1997
#
# name is Graham Pountney
# character is  Commentator
# number of episodes are 2
#
# name is Sam White
# character is  Rexal
# number of episodes are 2
#
# name is Andy Smith
# character is  Eco Tourist #2
# number of episodes are 2
#
# name is Angela Vermeir
# character is  Computer
# number of episodes are 2
#
# name is Jack Carr
# character is  Bellhop
# number of episodes are 2
#
# name is Sherry White
# character is  Middle aged woman
# number of episodes are 2
#
# name is Mike Petersen
# character is  790 Robot
# number of episodes are 2
#
# name is Maury Chaykin
# character is  Pa Gollean
# number of episodes are 1999
#
# name is Lisa Hynes
# character is  Original Xev
# number of episodes are 2
#
# name is Malcolm Younger
# character is  Priest
# number of episodes are 2000
#
# name is Amy Kerr
# character is  Desh
# number of episodes are 1
#
# name is Jeri-Matti Helppi
# character is  Peasant 1 episode, 2001
# number of episodes are 2001
#
# name is Cindy Sampson
# character is  Druid Girl
# number of episodes are 1
#
# name is Joshua Young
# character is  Black Pawn #3
# number of episodes are 1
#
# name is Tom Tasse
# character is  C.G. 1 episode, 1999
# number of episodes are 1999
#
# name is Gordon Patrick White
# character is  Thief
# number of episodes are 1
#
# name is Simon Licht
# character is  Dr. Kazan 1 episode, 1998
# number of episodes are 1998
#
# name is Lenore Zann
# character is  The Dark Lady 1 episode, 1999
# number of episodes are 1999
#
# name is Page Fletcher
# character is  Captain Jebbed 1 episode, 1999
# number of episodes are 1999
#
# name is Nina Franoszek
# character is  Grand Prosecutor Jihana 1 episode, 1999
# number of episodes are 1999
#
# name is Earl Pastko
# character is  Brizon 1 episode, 1999
# number of episodes are 1999
#
# name is Andrew Bigelow
# character is  Enox 1 episode, 1999
# number of episodes are 1999
#
# name is Matthew Burton
# character is  Brother Randor 1 episode, 1999
# number of episodes are 1999
#
# name is Jeremy Webb
# character is  Master of Ceremonies 1 episode, 1999
# number of episodes are 1999
#
# name is Richard Braine
# character is  Card Carrying Druid 1 episode, 2001
# number of episodes are 2001
#
# name is Nick Cawdron
# character is  Deputy Festus Trout 1 episode, 2002
# number of episodes are 2002
#
# name is Tim Curry
# character is  Poet Man 1 episode, 1997
# number of episodes are 1997
#
# name is Andy Jones
# character is  Smoor 1 episode, 1997
# number of episodes are 1997
#
# name is Wayne Robson
# character is  Gubby Mok 1 episode, 1999
# number of episodes are 1999
#
# name is Mary Walsh
# character is  Heedia 1 episode, 1999
# number of episodes are 1999
#
# name is Andrew Bush
# character is  Tad 1 episode, 1999
# number of episodes are 1999
#
# name is Susan Quinn
# character is  Sissy Gollean 1 episode, 1999
# number of episodes are 1999
#
# name is Diego Chambers
# character is  Aulk 1 episode, 1999
# number of episodes are 1999
#
# name is Matthias Klimsa
# character is  Brother Treygor 1 episode, 1999
# number of episodes are 1999
#
# name is Barbara Schmied
# character is  Slinka 1 episode, 1999
# number of episodes are 1999
#
# name is Polly Jo Pleasence
# character is  Rivet 1 episode, 2000
# number of episodes are 2000
#
# name is Julia Haacke
# character is  Lily 1 episode, 2000
# number of episodes are 2000
#
# name is David Christoffel
# character is  Cellphone Druid 1 episode, 2001
# number of episodes are 2001
#
# name is Britt Ekland
# character is  Dulcibella Sternflanks 1 episode, 2002
# number of episodes are 2002
#
# name is Polly Green
# character is  Amber 1 episode, 2002
# number of episodes are 2002
#
# name is Kathryn Fraser
# character is  Bereaved Mom 1 episode, 2002
# number of episodes are 2002
#
# name is Sandra Keller
# character is  Nurse
# number of episodes are 1999
#
# name is Dave Carmichael
# character is  Junior Gollean 1 episode, 1999
# number of episodes are 1999
#
# name is Sharon Timmins
# character is  Groo 1 episode, 1999
# number of episodes are 1999
#
# name is Sandra S. Leonhard
# character is  Tish 1 episode, 2000
# number of episodes are 2000
#
# name is Terry Neason
# character is  Wench 1 episode, 2000
# number of episodes are 2000
#
# name is Hephzibah Tintner
# character is  Tulip 1 episode, 2000
# number of episodes are 2000
#
# name is Nicole Ciroth
# character is  Minx 1 episode, 2000
# number of episodes are 2000
#
# name is Nick Ewans
# character is  Colin 1 episode, 2001
# number of episodes are 2001
#
# name is Michael Best
# character is  Merle 1 episode, 2001
# number of episodes are 2001
#
# name is Celia Henebury
# character is  Didi Figgleshrick 1 episode, 2002
# number of episodes are 2002
#
# name is Mason Phillips
# character is  Wyatt 1 episode, 2002
# number of episodes are 2002
#
# name is Donald Chisholm
# character is  FBI Lieutenant 1 episode, 2002
# number of episodes are 2002
#
# name is Barry Bostwick
# character is  Thodin 1 episode, 1996
# number of episodes are 1996
#
# name is Malcolm McDowell
# character is  Yottskry 1 episode, 1997
# number of episodes are 1997
#
# name is Gerry Wolff
# character is  Snik 1 episode, 1997
# number of episodes are 1997
#
# name is Kate Rose
# character is  Holo Woman 1 episode, 1997
# number of episodes are 1997
#
# name is Roman Podhora
# character is  L.L. Boosh 1 episode, 1998
# number of episodes are 1998
#
# name is Oliver Stern
# character is  Dr. Funz 1 episode, 1998
# number of episodes are 1998
#
# name is Benjamin Sadler
# character is  Nool 1 episode, 1999
# number of episodes are 1999
#
# name is Ellen-Ray Hennessy
# character is  Rissha 1 episode, 1999
# number of episodes are 1999
#
# name is Nikki Barnett
# character is  Kanana 1 episode, 1999
# number of episodes are 1999
#
# name is Kerry McPherson
# character is  Skye 1 episode, 1999
# number of episodes are 1999
#
# name is Paul McQuillan
# character is  Kyoo 1 episode, 1999
# number of episodes are 1999
#
# name is Diane Langton
# character is  Hammer 1 episode, 2000
# number of episodes are 2000
#
# name is Urs Remond
# character is  Cab 1 episode, 2000
# number of episodes are 2000
#
# name is Udo Jolly
# character is  Dr. Bunz 1 episode, 2000
# number of episodes are 2000
#
# name is Sabrina Rattey
# character is  Daisy 1 episode, 2000
# number of episodes are 2000
#
# name is Peter Blake
# character is  Oliver 1 episode, 2001
# number of episodes are 2001
#
# name is Tim Frances
# character is  Puck 1 episode, 2001
# number of episodes are 2001
#
# name is Howard Attfield
# character is  Executive 1 episode, 2001
# number of episodes are 2001
#
# name is Agumeuay Nakanakis
# character is  Native American Leader 1 episode, 2001
# number of episodes are 2001
#
# name is Danielle Dawe
# character is  Tourist 1 episode, 2001
# number of episodes are 2001
#
# name is Lois Brown
# character is  Older Woman 1 episode, 2001
# number of episodes are 2001
#
# name is Johnny Lomas
# character is  Josh 1 episode, 2002
# number of episodes are 2002
#
# name is Andrulla Blanchette
# character is  Queen of Sheba 1 episode, 2002
# number of episodes are 2002
#
# name is John Diamond
# character is  Burl 1 episode, 2002
# number of episodes are 2002
#
# name is Rachel Grover
# character is  Zev's Mother 1 episode, 1997
# number of episodes are 1997
#
# name is Barbara Geiger
# character is  Dr. Veezra 1 episode, 1998
# number of episodes are 1998
#
# name is David Lewis
# character is  Fruitcake 1 episode, 1999-2000
# number of episodes are 1
#
# name is Stacy Smith
# character is  Calico 1 episode, 1999
# number of episodes are 1999
#
# name is Susanna Metzner
# character is  Lissha 1 episode, 1999
# number of episodes are 1999
#
# name is Martin Höner
# character is  Older Brother 1 episode, 1999
# number of episodes are 1999
#
# name is Bruce Fillmore
# character is  Gibble 1 episode, 1999
# number of episodes are 1999
#
# name is Joe Wynn
# character is  New Born 1 episode, 1999
# number of episodes are 1999
#
# name is Ina Paule Klink
# character is  Daffodil 1 episode, 2000
# number of episodes are 2000
#
# name is Jelena Budimir
# character is  Socket 1 episode, 2000
# number of episodes are 2000
#
# name is Hans Brückner
# character is  Zin 1 episode, 2000
# number of episodes are 2000
#
# name is Katrin Schrake
# character is  Fox 1 episode, 2000
# number of episodes are 2000
#
# name is Craig Charles
# character is  The Warden 1 episode, 2001
# number of episodes are 2001
#
# name is Jay Benedict
# character is  Vet 1 episode, 2001
# number of episodes are 2001
#
# name is Brian Buckley
# character is  George 1 episode, 2001
# number of episodes are 2001
#
# name is Alexis Conran
# character is  Mustafa Al Hambra 1 episode, 2001
# number of episodes are 2001
#
# name is Bob Dearden
# character is  Dale 1 episode, 2001
# number of episodes are 2001
#
# name is Patrick Gordon
# character is  Oberon 1 episode, 2001
# number of episodes are 2001
#
# name is Rupert Evans
# character is  Cleasby 1 episode, 2002
# number of episodes are 2002
#
# name is Rebecca Mordan
# character is  Haley 1 episode, 2002
# number of episodes are 2002
#
# name is Kevin Deagle
# character is  A.F.R. #1 1 episode, 2002
# number of episodes are 2002
#
# name is Hussi Kutlucan
# character is  Orlluk 1 episode, 1997
# number of episodes are 1997
#
# name is Eva Ebner
# character is  Mrs. Deebee 1 episode, 1998
# number of episodes are 1998
#
# name is Burgandy Code
# character is  Navigator 1 episode, 1998
# number of episodes are 1998
#
# name is Tom Petry Strauss
# character is  Brother Deal 1 episode, 1999
# number of episodes are 1999
#
# name is Peter Scollin
# character is  Guard 1 1 episode, 1999
# number of episodes are 1999
#
# name is Lee-Anne Lowe
# character is  Dream Girl #1 1 episode, 1999
# number of episodes are 1999
#
# name is Karl Lewis Johnston
# character is  Glootus 1 episode, 1999
# number of episodes are 1999
#
# name is Robin Johnson
# character is  Guard #1 1 episode, 1999
# number of episodes are 1999
#
# name is Rosemarie Friedrich
# character is  The Wife 1 episode, 1999
# number of episodes are 1999
#
# name is Katja Richter
# character is  Lynx 1 episode, 2000
# number of episodes are 2000
#
# name is David Matheson
# character is  ATF Agent 1 episode, 2001
# number of episodes are 2001
#
# name is Rejean Cournoyer
# character is  Earl 1 episode, 2001
# number of episodes are 2001
#
# name is David Charles
# character is  Boy 1 episode, 2001
# number of episodes are 2001
#
# name is Mike Daly
# character is  ATF Agent 1 episode, 2001
# number of episodes are 2001
#
# name is Stan Carew
# character is  French Diplomat 1 episode, 2001
# number of episodes are 2001
#
# name is Karen Beverly
# character is  Journalist #2 1 episode, 2001
# number of episodes are 2001
#
# name is Giovanni del Vecchio
# character is  Marconi 1 episode, 2001
# number of episodes are 2001
#
# name is Togo Igawa
# character is  Monk 1 episode, 2002
# number of episodes are 2002
#
# name is Finlay Robertson
# character is  Ryan 1 episode, 2002
# number of episodes are 2002
#
# name is Rory MacGregor
# character is  Mort the Mortician 1 episode, 2002
# number of episodes are 2002
#
# name is Doug Barron
# character is  Secretary of Defense 1 episode, 2002
# number of episodes are 2002
#
# name is Shawn Duggan
# character is  Survivalist #2 1 episode, 2002
# number of episodes are 2002
#
# name is Dennis Envoldsen
# character is  Corporal Harrison Birdie 1 episode, 2002
# number of episodes are 2002
#
# name is Hans-Dieter Brückner
# character is  Grullek 1 episode, 1997
# number of episodes are 1997
#
# name is Errol Shaker
# character is  Administrator 1 episode, 1998
# number of episodes are 1998
#
# name is John Davie
# character is  Rockhound 1 episode, 1998
# number of episodes are 1998
#
# name is Noah Dalton Danby
# character is  Varrtan 1 episode, 1999
# number of episodes are 1999
#
# name is C.J. Lusby
# character is  Nympho 1 1 episode, 1999
# number of episodes are 1999
#
# name is Harvey Friedman
# character is  Guard 3 1 episode, 1999
# number of episodes are 1999
#
# name is Christian Murray
# character is  792 1 episode, 1999
# number of episodes are 1999
#
# name is Lorraine Segato
# character is  Time Prophet 1 episode, 1999
# number of episodes are 1999
#
# name is Philippe Roche
# character is  Brother Stack
# number of episodes are 1999
#
# name is Christian Murray
# character is  Gold Lamé Man 1 episode, 1999
# number of episodes are 1999
#
# name is Jimmy Somerville
# character is  Satin 1 episode, 2000
# number of episodes are 2000
#
# name is Rose Zone
# character is  Bruise 1 episode, 2000
# number of episodes are 2000
#
# name is Clive Merrison
# character is  Professor Shnoog 1 episode, 2001
# number of episodes are 2001
#
# name is Alun Lewis
# character is  Uther de Glastonbury, formerly known as Nigel Bumsen 1 episode, 2001
# number of episodes are 2001
#
# name is John Gleeson
# character is  Doctor 1 episode, 2001
# number of episodes are 2001
#
# name is David Francis
# character is  Newfie 1 episode, 2001
# number of episodes are 2001
#
# name is Lee J. Campbell
# character is  Journalist #1 1 episode, 2001
# number of episodes are 2001
#
# name is Melanie Harris
# character is  Marjorie 1 episode, 2001
# number of episodes are 2001
#
# name is James Crossley
# character is  Chad 1 episode, 2001
# number of episodes are 2001
#
# name is Philip Dinn
# character is  Local 1 episode, 2001
# number of episodes are 2001
#
# name is Seán Cullen
# character is  Remo 1 episode, 2002
# number of episodes are 2002
#
# name is Richard Hanson
# character is  Devlin 1 episode, 2002
# number of episodes are 2002
#
# name is Geoffrey McLean
# character is  Middle Aged Son 1 episode, 2002
# number of episodes are 2002
#
# name is Rainer Matsutani
# character is  Brunnen-G General 1 episode, 1997
# number of episodes are 1997
#
# name is Arno Wyzniewski
# character is  Kuk 1 episode, 1997
# number of episodes are 1997
#
# name is Ian T. Dickinson
# character is  Berg 1 episode, 1998
# number of episodes are 1998
#
# name is Milton Welsh
# character is  Rat II 1 episode, 1999
# number of episodes are 1999
#
# name is Thorsten Feller
# character is  Liggum 1 episode, 1999
# number of episodes are 1999
#
# name is Amy Lonergan
# character is  Dream Girl #3 1 episode, 1999
# number of episodes are 1999
#
# name is Alison McMullin
# character is  Nympho 2 1 episode, 1999
# number of episodes are 1999
#
# name is Paul Day
# character is  Consort 1 episode, 1999
# number of episodes are 1999
#
# name is Dick Sircom
# character is  Judge 1 episode, 1999
# number of episodes are 1999
#
# name is Adrienne Horton
# character is  Guard #3 1 episode, 1999
# number of episodes are 1999
#
# name is Peter Baylis
# character is  First Balloonist 1 episode, 2000
# number of episodes are 2000
#
# name is Lionel Jeffries
# character is  Father Borscht 1 episode, 2001
# number of episodes are 2001
#
# name is Mick Walter
# character is  Titania 1 episode, 2001
# number of episodes are 2001
#
# name is Jim Fowler
# character is  Rooster 1 episode, 2001
# number of episodes are 2001
#
# name is Ken Shipley
# character is  Produce Manager 1 episode, 2001
# number of episodes are 2001
#
# name is Tom Haney
# character is  Studio Guard 1 episode, 2001
# number of episodes are 2001
#
# name is Sam Douglas
# character is  General Klebstock 1 episode, 2002
# number of episodes are 2002
#
# name is Mike Durling
# character is  Joey 1 episode, 2002
# number of episodes are 2002
#
# name is Michael Habeck
# character is  Feppo 1 episode, 1997-1999
# number of episodes are 1
#
# name is Tatjana Alexander
# character is  Nurse 1 episode, 1998
# number of episodes are 1998
#
# name is Gabi Fleming
# character is  Dead Female Body 1 episode, 1999
# number of episodes are 1999
#
# name is Lori Heath
# character is  Hologram Guard 1 episode, 1999
# number of episodes are 1999
#
# name is Adrian Mattiske
# character is  Young Copying Brother 1 episode, 1999
# number of episodes are 1999
#
# name is Janaya Stephens
# character is  Peach 1 episode, 2000
# number of episodes are 2000
#
# name is Keith-Lee Castle
# character is  Renfield 1 episode, 2001
# number of episodes are 2001
#
# name is Jeremy Peters
# character is  Surgeon 1 episode, 2001
# number of episodes are 2001
#
# name is Jason Hemsworth
# character is  Secret Service Agent 1 episode, 2001
# number of episodes are 2001
#
# name is Andrea Dymond
# character is  Goth Prisoner 1 episode, 2001
# number of episodes are 2001
#
# name is Michael J. Reynolds
# character is  Colonel Donald K. Gore 1 episode, 2002
# number of episodes are 2002
#
# name is William Parsons
# character is  Older Husband 1 episode, 2002
# number of episodes are 2002
#
# name is Nancy Marshall
# character is  Geekette 1 episode, 2002
# number of episodes are 2002
#
# name is Rick Collins
# character is  Fat Man 1 episode, 1999
# number of episodes are 1999
#
# name is Greg Cormier
# character is  Bound Man 1 episode, 1999
# number of episodes are 1999
#
# name is Thomas Arnicke
# character is  Bodyguard 1 episode, 1999
# number of episodes are 1999
#
# name is Wanja Mues
# character is  Pearl 1 episode, 2000
# number of episodes are 2000
#
# name is Robyn Palmer
# character is  Pear 1 episode, 2000
# number of episodes are 2000
#
# name is Martha Irving
# character is  Doris 1 episode, 2001
# number of episodes are 2001
#
# name is Travis Ferris
# character is  Guard #2 1 episode, 2001
# number of episodes are 2001
#
# name is Kevin LeBlanc
# character is  FBI Agent #1 1 episode, 2002
# number of episodes are 2002
#
# name is Mary Alvena Poole
# character is  Older Wife 1 episode, 2002
# number of episodes are 2002
#
# name is Paul Jessen
# character is  ATF Officer 1 episode, 2002
# number of episodes are 2002
#
# name is Jim Petrie
# character is  Gorrett 1 episode, 1997
# number of episodes are 1997
#
# name is Terry Nicholas
# character is  First Babe 1 episode, 1999
# number of episodes are 1999
#
# name is Al Mueller
# character is  Bodyguard 1 episode, 1999
# number of episodes are 1999
#
# name is Roberta Angelica
# character is  Plum 1 episode, 2000
# number of episodes are 2000
#
# name is Roger Tebb
# character is  Silk 1 episode, 2000
# number of episodes are 2000
#
# name is Robert Maillet
# character is  Leroy 1 episode, 2001
# number of episodes are 2001
#
# name is Frank Kelly
# character is  Father Pickle 1 episode, 2001
# number of episodes are 2001
#
# name is Richard Hards
# character is  Nelson 1 episode, 2001
# number of episodes are 2001
#
# name is Arthur Spray
# character is  Gypsy Servant 1 episode, 2001
# number of episodes are 2001
#
# name is Bill Jessome
# character is  Chief Justice 1 episode, 2001
# number of episodes are 2001
#
# name is Kelsa Kinsly
# character is  Slave Girl 88 1 episode, 2002
# number of episodes are 2002
#
# name is Jesse Lund
# character is  Rod 1 episode, 2002
# number of episodes are 2002
#
# name is Stephanie Redding
# character is  Twin Daughter 1 episode, 2002
# number of episodes are 2002
#
# name is Sherry Devanney
# character is  Kyyra 1 episode, 1997
# number of episodes are 1997
#
# name is Lisa Wong
# character is  Second Babe 1 episode, 1999
# number of episodes are 1999
#
# name is Dave Maddeaux
# character is  Male Customer 1 episode, 1999
# number of episodes are 1999
#
# name is Mirko Szabo
# character is  Bodyguard 1 episode, 1999
# number of episodes are 1999
#
# name is Mika Ward
# character is  Cherry 1 episode, 2000
# number of episodes are 2000
#
# name is Georg Tryphon
# character is  Lace 1 episode, 2000
# number of episodes are 2000
#
# name is John Standing
# character is  Count Dracul 1 episode, 2001
# number of episodes are 2001
#
# name is Chris Owens
# character is  Biff 1 episode, 2001
# number of episodes are 2001
#
# name is Hattie Hayridge
# character is  Sub-Warden Heidi 1 episode, 2001
# number of episodes are 2001
#
# name is Bette MacDonald
# character is  Marge 1 episode, 2001
# number of episodes are 2001
#
# name is Madeleine Lefebvre
# character is  Eco Tourist #1 1 episode, 2001
# number of episodes are 2001
#
# name is Gareth Miller
# character is  Lieutenant 1 episode, 2001
# number of episodes are 2001
#
# name is John Lebar
# character is  The Mummy - Draco 1 episode, 2002
# number of episodes are 2002
#
# name is Ryan McCluskey
# character is  Tad 1 episode, 2002
# number of episodes are 2002
#
# name is Nicole Redding
# character is  Dead Twin Daughter 1 episode, 2002
# number of episodes are 2002
#
# name is Cleveland Sauer
# character is  Survivalist 1 episode, 2002
# number of episodes are 2002
#
# name is Joel Sapp
# character is  Bleeding Cleric
# number of episodes are 1997
#
# name is Sebastian Kokot
# character is  Bodyguard 1 episode, 1999
# number of episodes are 1999
#
# name is Renate Spona
# character is  Guard #1 1 episode, 2000
# number of episodes are 2000
#
# name is Ed Macdonald
# character is  Leo 1 episode, 2001
# number of episodes are 2001
#
# name is Maggie Holland
# character is  Elderly Lady 1 episode, 2001
# number of episodes are 2001
#
# name is Nunzio Lombardo
# character is  Valentino 1 episode, 2001
# number of episodes are 2001
#
# name is Stephen Morgan
# character is  Chip 1 episode, 2001
# number of episodes are 2001
#
# name is Dan Steeves
# character is  Store Guard 1 episode, 2001
# number of episodes are 2001
#
# name is Marguerite McNeil
# character is  Stress Counselor 1 episode, 2002
# number of episodes are 2002
#
# name is Dominic Pallotta
# character is  Frankie 1 episode, 2002
# number of episodes are 2002
#
# name is Oliver Stolz
# character is  Bodyguard 1 episode, 1999
# number of episodes are 1999
#
# name is Sabine Winterfeldt
# character is  Guard #2 1 episode, 2000
# number of episodes are 2000
#
# name is Ross O'Hennessy
# character is  Cedric 1 episode, 2001
# number of episodes are 2001
#
# name is Alec Linstead
# character is  Cardinal Meinpo Duftet 1 episode, 2001
# number of episodes are 2001
#
# name is Douglas Mayr
# character is  Bartender 1 episode, 2001
# number of episodes are 2001
#
# name is James Reeve
# character is  Sheriff 1 episode, 2001
# number of episodes are 2001
#
# name is Laura Patch
# character is  Piccalina 1 episode, 2002
# number of episodes are 2002
#
# name is Jeremiah Sparks
# character is  Cabbie 1 episode, 2002
# number of episodes are 2002
#
# name is Thordis König
# character is  Guard #3 1 episode, 2000
# number of episodes are 2000
#
# name is David Verrey
# character is  Businessman 1 episode, 2001
# number of episodes are 2001
#
# name is Justin Pierre
# character is  Bob 1 episode, 2001
# number of episodes are 2001
#
# name is Rhonda McLean
# character is  Mom 1 episode, 2001
# number of episodes are 2001
#
# name is Julia Moore
# character is  Truro 1 episode, 2001
# number of episodes are 2001
#
# name is Lydia Klenck
# character is  Shower Nude #1 1 episode, 2001
# number of episodes are 2001
#
# name is Tricia Taylor
# character is  Love Slave Wrestler 1 episode, 2002
# number of episodes are 2002
#
# name is Jason Sweeney
# character is  Rex 1 episode, 2002
# number of episodes are 2002
#
# name is Lenuta Sim
# character is  Dancing Twin #2 1 episode, 1997
# number of episodes are 1997
#
# name is Gina Fischer
# character is  Guard #4 1 episode, 2000
# number of episodes are 2000
#
# name is Craig Wood
# character is  Chief Guard 1 episode, 2000
# number of episodes are 2000
#
# name is Silvio Simac
# character is  Hank 1 episode, 2001
# number of episodes are 2001
#
# name is Heather Rankin
# character is  Phoebe 1 episode, 2001
# number of episodes are 2001
#
# name is John Pearson
# character is  Cobra 1 episode, 2001
# number of episodes are 2001
#
# name is Beth Mahaney
# character is  Shower Nude #2 1 episode, 2001
# number of episodes are 2001
#
# name is Bruce Murphy
# character is  Junior 1 episode, 2001
# number of episodes are 2001
#
# name is Heidi von Palleske
# character is  Slave Girl 24 1 episode, 2002
# number of episodes are 2002
#
# name is Matt Zimmerman
# character is  Supervisor 1 episode, 2002
# number of episodes are 2002
#
# name is Mariana Sim
# character is  Dancing Twin #1 1 episode, 1997
# number of episodes are 1997
#
# name is Jana Piehl
# character is  Guard #5 1 episode, 2000
# number of episodes are 2000
#
# name is Jamie Sparks
# character is  Passenger 1 episode, 2001
# number of episodes are 2001
#
# name is Peter James
# character is  Guard #1 1 episode, 2001
# number of episodes are 2001
#
# name is Raymond Solomon
# character is  Jacques 1 episode, 2001
# number of episodes are 2001
#
# name is Maisie Rillie
# character is  Sharon 1 episode, 2001
# number of episodes are 2001
#
# name is Andy Gatjen
# character is  Ridolan 1 episode, 2001
# number of episodes are 2001
#
# name is Shooglenifty
# character is  Themselves 1 episode, 2001
# number of episodes are 2001
#
# name is Rupert Solomon
# character is  Pierce 1 episode, 2001
# number of episodes are 2001
#
# name is Marcos Troy
# character is  Malik 1 episode, 2001
# number of episodes are 2001
#
# name is Malcolm Cosbie
# character is  Self - Band 1 episode, 2001
# number of episodes are 2001
#
# name is David Woods
# character is  Yoyal 1 episode, 1997
# number of episodes are 1997
#
# name is Georgia Zaris
# character is  Farley's Assistant 1 episode, 2001
# number of episodes are 2001
#
# name is Jim Swansburg
# character is  Cmdr. Bricklin 1 episode, 2001
# number of episodes are 2001
#
# name is Garry Finlayson
# character is  Self - Band 1 episode, 2001
# number of episodes are 2001
#
# name is Craig Gaskin
# character is  Self - Band 1 episode, 2001
# number of episodes are 2001
#
# name is Josh MacDonald
# character is  Sergeant 1 episode, 1996
# number of episodes are 1996
#
# name is Angus Grant
# character is  Self - Band 1 episode, 2001
# number of episodes are 2001
#
# name is Ian MacLeod
# character is  Self - Band 1 episode, 2001
# number of episodes are 2001
#
# name is Conrad Molleson
# character is  Self - Band 1 episode, 2001
# number of episodes are 2001
#
# name is Horst Ulan
# character is  Cluster General 1 episode, 1996
# number of episodes are 1996
#
# name is Stephen J. Turnbull
# character is  Fore Shadow Officer 1 episode, 1996
# number of episodes are 1996
#
# name is Andrew Smith
# character is  Cleric 1 episode, 1996
# number of episodes are 1996
#
# name is Janice Evens
# character is  Computer 1 episode, 1996
# number of episodes are 1996
#
# name is Marty Simon
# character is  Brain No. 14 1 episode, 1996
# number of episodes are 1996
#
# name is Elizabeth Richardson
# character is  Holo Prosecutor 1 episode, 1996-1997
# number of episodes are 1
#
# name is Joseph Rutten
# character is  Slab Prisoner 1 episode, 1996
# number of episodes are 1996
#
# name is Chris Rowntree
# character is  Holo Official 1 episode, 1996
# number of episodes are 1996
#
# name is Rutger Hauer
# character is  Bog 1 episode, 1997
# number of episodes are 1997
#
# name is Doreen Jacobi
# character is  Wist 1 episode, 1997
# number of episodes are 1997
#
# name is Darcy Lindzon
# character is  Air Force One Attendant 1 episode, 2002
# number of episodes are 2002
#
# name is David Alexander Miller
# character is  Duke's Guard
# number of episodes are 2
#
# name is J. William Grantham
# character is  ATF Agent (uncredited) 2 episodes, 2001
# number of episodes are 2001
#
# name is Rick Courtney
# character is  790 (uncredited) 1 episode, 1996
# number of episodes are 1996
#
# name is Alexander Baier
# character is  Additional Girl (uncredited) 1 episode, 2000
# number of episodes are 2000
#
# name is Craig Dawson
# character is  Klassp (uncredited) 1 episode, 2000
# number of episodes are 2000
#
# name is Nikki McLean
# character is  Background (uncredited) 1 episode, 2001
# number of episodes are 2001
#
# name is Hank White
# character is  French Diplomat (uncredited) 1 episode, 2001
# number of episodes are 2001

# %% [markdown]
# **Lab 3: Excercise 3 from PDF**
# Let’s bundle all the code we’ve been experimenting with into a few classes that “encapsulate” what
# we’ve learned about IMDb API record formats.
#
# • Define a TvSeries class. The init method takes the id for an IMDb TV Series, fetches the record
# and stores some key values (like id, title, date). You should define a helper method to parse
# the date from the description field.
#
# • Define an Actor class. The init method takes the id for an IMDb Actor, fetches the record, and
# stores some key values (like id, name, birthDate)
#
# • Define a Character class. The init method takes a TVSeries object and an Actor object, along
# with name of the character played by that Actor, and the number of episodes they were in.
#
# • Add an accessor method to your TvSeries class to get a rating for the series. Take one
# parameter, the type of rating, and return the rating, if available, otherwise None.
#
# • Add an accessor method to your TvSeries class to get a list of Character objects for the series.
# You will need the parse functions you wrote in Lab 2, consider integrating them here as helper
# methods.
#
# Add a new code block with a little code that tests all of your classes are working as expected.
# Feel free to have fun extending these models in various ways – the possibilities are endless.
# Notice that what we are doing here is “wrapping” the http web API in a simpler, easy to use Python
# API that hides all the details of how the web API works. This is an example of one of the most
# important principles in Computer Science: The Principle of Information Hiding

# %%
class TvSeries:

  def getTitle(jsonText):
    fullTitle = jsonText['fullTitle']
    name = ''
    unFltrdWrd = fullTitle.split(' ')
    for item in unFltrdWrd:
      if('(' in item):
        break
      else:
        name = name + ' ' + item
    return name
    
  def __init__(self, TvID):
    url = "https://imdb-api.com/en/API/Title/{key}/{title}".format(key=API_KEY, title=TvID)
    response = requests.request("GET", url, headers={}, data={})
    data = json.loads(response.text)

    self.Title = TvSeries.getTitle(data)
    self.id = data['id']
    self.date = data['year']
    self.data = data

  def __str__(self):
    return 'Title: ' + str(self.Title) + '\nid: ' + str(self.id) + '\ndate: ' + str(self.date) + '\n'

  def getRating(self):
    return self.data['imDbRating']

  def createCharacterObjects(self):
    actors = self.data['actorList']
    objectList = [Character( TvSeries(self.id), Actor(item['id'])) for item in actors]
    return objectList

class Actor:

  def __init__(self, ActorID):
    url = "https://imdb-api.com/en/API/Name/{key}/{name}".format(key=API_KEY, name=ActorID)
    response = requests.request("GET", url, headers={}, data={})
    data = json.loads(response.text)

    self.name =  data['name']
    self.id = data['id']
    self.BirthDate = data['birthDate']

  def __str__(self):
    return 'Name: ' + str(self.name) + '\nid: ' + str(self.id) + '\nBirthday: ' + str(self.BirthDate) + '\n'

class Character:

  def __init__(self, TvSeries, Actor):
    self.character = ''
    self.numberOfEpisodes = ''
    data = TvSeries.data
    List = [{ 'actor': item['name'], 'character': item["asCharacter"] } for item in data['actorList']]

    for item in List:
      if (Actor.name in item['actor']):
        self.character = returnCharacterName(item['character'])
        self.numberOfEpisodes = returnNumberOfEpisodes(item['character'])

  def __str__(self):
    return 'Character: ' + str(self.character) + '\nNumber of Episodes which they appear in: ' + str(self.numberOfEpisodes) + '\n'

a = TvSeries('tt0115243')
print(a)
b = Actor('nm0235978')
print(b)
c = Character(TvSeries('tt0115243'), Actor('nm0235978'))
print(c)
TvSeries('tt0115243').getRating
d = TvSeries('tt0115243').createCharacterObjects()
for i in d:
  print(i)
# Out:
# Title:  Lexx
# id: tt0115243
# date: 1996
#
# Name: Brian Downey
# id: nm0235978
# Birthday: 1944-10-31
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-b20167d43f59> in <module>()
#      68 b = Actor('nm0235978')
#      69 print(b)
# ---> 70 c = Character(TvSeries('tt0115243'), Actor('nm0235978'))
#      71 print(c)
#      72 TvSeries('tt0115243').getRating
#
# <ipython-input-69-b20167d43f59> in __init__(self, TvID)
#      18     data = json.loads(response.text)
#      19
# ---> 20     self.Title = TvSeries.getTitle(data)
#      21     self.id = data['id']
#      22     self.date = data['year']
#
# <ipython-input-69-b20167d43f59> in getTitle(jsonText)
#       5     fullTitle = jsonText['fullTitle']
#       6     name = ''
# ----> 7     unFltrdWrd = fullTitle.split(' ')
#       8     for item in unFltrdWrd:
#       9       if('(' in item):
#
# AttributeError: 'NoneType' object has no attribute 'split'
